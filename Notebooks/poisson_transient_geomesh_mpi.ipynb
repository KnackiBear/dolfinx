# %%
## Parallel programming imports
import ipyparallel as ipp
from mpi4py import MPI
cluster = ipp.Cluster(engines = "mpi", n = 9) 
rc = cluster.start_and_connect_sync()
# Out:
# Starting 9 engines with <class 'ipyparallel.cluster.launcher.MPIEngineSetLauncher'>
#   0%|          | 0/9 [00:00<?, ?engine/s]

# %%
# %%px
#
# import importlib.util
#
# if importlib.util.find_spec("petsc4py") is not None:
#     import dolfinx
#
#     if not dolfinx.has_petsc:
#         print("This demo requires DOLFINx to be compiled with PETSc enabled.")
#         exit(0)
#     from petsc4py.PETSc import ScalarType  # type: ignore
# else:
#     print("This demo requires petsc4py.")
#     exit(0)
#
# from mpi4py import MPI
#
# # +
# import numpy as np
#
# import ufl
# from dolfinx import fem, io, mesh, plot, la
# from dolfinx.fem.petsc import LinearProblem
# import matplotlib.pyplot as plt
#
# import time
# import copy

# %%
# %%px
#
#
# import gmsh
# from dolfinx.io import gmshio
# from dolfinx.graph import partitioner_scotch
# from dolfinx.io import XDMFFile, VTXWriter
#
# gmsh.initialize()
# gmsh.open("BoxMesh.geo")
# model = gmsh.model
# model_name = model.getCurrent()
#
# #partitioner = dolfinx.mesh.create_cell_partitioner(partitioner_scotch())
# partitioner = mesh.create_cell_partitioner(mesh.GhostMode.shared_facet)
# umesh, ucell_tags, ufacet_tags = gmshio.model_to_mesh(
#     model,
#     MPI.COMM_WORLD,
#     rank = 0,
#     gdim = 3,
#     partitioner = partitioner
# )
#
#
# gmsh.finalize()
# #mesh, cell_tags, facet_tags = model_to_mesh(gmsh.model, MPI.COMM_WORLD, model_rank)
# Out:
# [stdout:3] Info    : Reading 'BoxMesh.geo'...
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000970807s, CPU 0.001239s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Transfinite)
# Info    : [ 20%] Meshing surface 2 (Transfinite)
# Info    : [ 40%] Meshing surface 3 (Transfinite)
# Info    : [ 60%] Meshing surface 4 (Transfinite)
# Info    : [ 70%] Meshing surface 5 (Transfinite)
# Info    : [ 90%] Meshing surface 6 (Transfinite)
# Info    : Done meshing 2D (Wall 0.00373262s, CPU 0.003987s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 1 volume with 1 connected component
# Info    : Tetrahedrizing 15368 nodes...
# Info    : Done tetrahedrizing 15376 nodes (Wall 0.278972s, CPU 0.269596s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 1006 Steiner points
# Info    : Done reconstructing mesh (Wall 1.86481s, CPU 1.85667s)
# Info    : It. 33000 - 27583 nodes created - worst tet radius 1.06503 (nodes removed 2 5415)
# Info    : It. 33500 - 28083 nodes created - worst tet radius 1.05848 (nodes removed 2 5415)
# Info    : It. 34000 - 28581 nodes created - worst tet radius 1.05281 (nodes removed 2 5417)
# Info    : It. 34500 - 29081 nodes created - worst tet radius 1.047 (nodes removed 2 5417)
# Info    : It. 35000 - 29577 nodes created - worst tet radius 1.04097 (nodes removed 2 5421)
# Info    : It. 35500 - 30077 nodes created - worst tet radius 1.03564 (nodes removed 2 5421)
# Info    : It. 36000 - 30574 nodes created - worst tet radius 1.03014 (nodes removed 2 5424)
# Info    : It. 36500 - 31071 nodes created - worst tet radius 1.02435 (nodes removed 2 5427)
# Info    : It. 37000 - 31565 nodes created - worst tet radius 1.01875 (nodes removed 2 5433)
# Info    : It. 37500 - 32058 nodes created - worst tet radius 1.01364 (nodes removed 2 5440)
# Info    : It. 38000 - 32557 nodes created - worst tet radius 1.00816 (nodes removed 2 5441)
# Info    : It. 38500 - 33055 nodes created - worst tet radius 1.00321 (nodes removed 2 5443)
# Info    : 3D refinement terminated (49758 nodes total):
# Info    :  - 2598 Delaunay cavities modified for star shapeness
# Info    :  - 5445 nodes could not be inserted
# Info    :  - 266400 tetrahedra created in 3.37627 sec. (78903 tets/s)
# Info    : 59 node relocations
# Info    : Done meshing 3D (Wall 8.08385s, CPU 8.08422s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 0.002) with worst = 0.00168568 / average = 0.748344:
# Info    : 0.00 < quality < 0.10 :       693 elements
# Info    : 0.10 < quality < 0.20 :      2046 elements
# Info    : 0.20 < quality < 0.30 :      4092 elements
# Info    : 0.30 < quality < 0.40 :      7147 elements
# Info    : 0.40 < quality < 0.50 :     10245 elements
# Info    : 0.50 < quality < 0.60 :     20392 elements
# Info    : 0.60 < quality < 0.70 :     36161 elements
# Info    : 0.70 < quality < 0.80 :     58669 elements
# Info    : 0.80 < quality < 0.90 :     83710 elements
# Info    : 0.90 < quality < 1.00 :     43245 elements
# Info    : 6035 edge swaps, 742 node relocations (volume = 0.002): worst = 0.00922743 / average = 0.761871 (Wall 0.337613s, CPU 0.338518s)
# Info    : 6265 edge swaps, 811 node relocations (volume = 0.002): worst = 0.0928029 / average = 0.762342 (Wall 0.455889s, CPU 0.457133s)
# Info    : 6286 edge swaps, 828 node relocations (volume = 0.002): worst = 0.134801 / average = 0.762368 (Wall 0.555568s, CPU 0.557545s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :        14 elements
# Info    : 0.20 < quality < 0.30 :       178 elements
# Info    : 0.30 < quality < 0.40 :      7170 elements
# Info    : 0.40 < quality < 0.50 :     10300 elements
# Info    : 0.50 < quality < 0.60 :     20355 elements
# Info    : 0.60 < quality < 0.70 :     35967 elements
# Info    : 0.70 < quality < 0.80 :     59645 elements
# Info    : 0.80 < quality < 0.90 :     84590 elements
# Info    : 0.90 < quality < 1.00 :     43157 elements
# Info    : Done optimizing mesh (Wall 1.43909s, CPU 1.43204s)
# Info    : 49635 nodes 292744 elements
# Info    : Done reading 'BoxMesh.geo'
# [stdout:2] Info    : Reading 'BoxMesh.geo'...
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000883606s, CPU 0.001119s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Transfinite)
# Info    : [ 20%] Meshing surface 2 (Transfinite)
# Info    : [ 40%] Meshing surface 3 (Transfinite)
# Info    : [ 60%] Meshing surface 4 (Transfinite)
# Info    : [ 70%] Meshing surface 5 (Transfinite)
# Info    : [ 90%] Meshing surface 6 (Transfinite)
# Info    : Done meshing 2D (Wall 0.00292902s, CPU 0.003165s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 1 volume with 1 connected component
# Info    : Tetrahedrizing 15368 nodes...
# Info    : Done tetrahedrizing 15376 nodes (Wall 0.333694s, CPU 0.324268s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 1006 Steiner points
# Info    : Done reconstructing mesh (Wall 1.92196s, CPU 1.91479s)
# Info    : Found volume 1
# Info    : It. 0 - 0 nodes created - worst tet radius 66.6495 (nodes removed 0 0)
# Info    : It. 500 - 21 nodes created - worst tet radius 36.9203 (nodes removed 0 479)
# Info    : It. 1000 - 61 nodes created - worst tet radius 16.0699 (nodes removed 0 939)
# Info    : It. 1500 - 117 nodes created - worst tet radius 18.1194 (nodes removed 0 1383)
# Info    : It. 2000 - 194 nodes created - worst tet radius 8.00763 (nodes removed 0 1806)
# Info    : It. 2500 - 278 nodes created - worst tet radius 6.73154 (nodes removed 0 2222)
# Info    : It. 3000 - 395 nodes created - worst tet radius 5.70927 (nodes removed 0 2605)
# Info    : It. 3500 - 542 nodes created - worst tet radius 4.82412 (nodes removed 0 2958)
# Info    : It. 4000 - 713 nodes created - worst tet radius 4.18385 (nodes removed 0 3287)
# Info    : It. 4500 - 929 nodes created - worst tet radius 3.67671 (nodes removed 0 3571)
# Info    : It. 5000 - 1215 nodes created - worst tet radius 3.22497 (nodes removed 0 3785)
# Info    : It. 5500 - 1500 nodes created - worst tet radius 2.93348 (nodes removed 0 4000)
# Info    : It. 6000 - 1803 nodes created - worst tet radius 3.60032 (nodes removed 0 4197)
# Info    : It. 6500 - 2172 nodes created - worst tet radius 2.54046 (nodes removed 0 4328)
# Info    : It. 7000 - 2562 nodes created - worst tet radius 2.39587 (nodes removed 0 4438)
# Info    : It. 7500 - 2955 nodes created - worst tet radius 2.27172 (nodes removed 0 4545)
# Info    : It. 8000 - 3366 nodes created - worst tet radius 2.16224 (nodes removed 0 4634)
# Info    : 0.10 < quality < 0.20 :      2046 elements
# Info    : 0.20 < quality < 0.30 :      4092 elements
# Info    : 0.30 < quality < 0.40 :      7147 elements
# Info    : 0.40 < quality < 0.50 :     10245 elements
# Info    : 0.50 < quality < 0.60 :     20392 elements
# Info    : 0.60 < quality < 0.70 :     36161 elements
# Info    : 0.70 < quality < 0.80 :     58669 elements
# Info    : 0.80 < quality < 0.90 :     83710 elements
# Info    : 0.90 < quality < 1.00 :     43245 elements
# Info    : 6035 edge swaps, 742 node relocations (volume = 0.002): worst = 0.00922743 / average = 0.761871 (Wall 0.324094s, CPU 0.324968s)
# Info    : 6265 edge swaps, 811 node relocations (volume = 0.002): worst = 0.0928029 / average = 0.762342 (Wall 0.447724s, CPU 0.448957s)
# Info    : 6286 edge swaps, 828 node relocations (volume = 0.002): worst = 0.134801 / average = 0.762368 (Wall 0.531641s, CPU 0.533521s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :        14 elements
# Info    : 0.20 < quality < 0.30 :       178 elements
# Info    : 0.30 < quality < 0.40 :      7170 elements
# Info    : 0.40 < quality < 0.50 :     10300 elements
# Info    : 0.50 < quality < 0.60 :     20355 elements
# Info    : 0.60 < quality < 0.70 :     35967 elements
# Info    : 0.70 < quality < 0.80 :     59645 elements
# Info    : 0.80 < quality < 0.90 :     84590 elements
# Info    : 0.90 < quality < 1.00 :     43157 elements
# Info    : Done optimizing mesh (Wall 1.39628s, CPU 1.39002s)
# Info    : 49635 nodes 292744 elements
# Info    : Done reading 'BoxMesh.geo'
# [stdout:0] Info    : Reading 'BoxMesh.geo'...
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000994707s, CPU 0.001196s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Transfinite)
# Info    : [ 20%] Meshing surface 2 (Transfinite)
# Info    : [ 40%] Meshing surface 3 (Transfinite)
# Info    : [ 60%] Meshing surface 4 (Transfinite)
# Info    : [ 70%] Meshing surface 5 (Transfinite)
# Info    : [ 90%] Meshing surface 6 (Transfinite)
# Info    : Done meshing 2D (Wall 0.00381063s, CPU 0.004054s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 1 volume with 1 connected component
# Info    : Tetrahedrizing 15368 nodes...
# Info    : Done tetrahedrizing 15376 nodes (Wall 0.309697s, CPU 0.300301s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 1006 Steiner points
# Info    : Done reconstructing mesh (Wall 1.65575s, CPU 1.64776s)
# Info    : Found volume 1
# Info    : It. 0 - 0 nodes created - worst tet radius 66.6495 (nodes removed 0 0)
# Info    : It. 33500 - 28083 nodes created - worst tet radius 1.05848 (nodes removed 2 5415)
# Info    : It. 34000 - 28581 nodes created - worst tet radius 1.05281 (nodes removed 2 5417)
# Info    : It. 34500 - 29081 nodes created - worst tet radius 1.047 (nodes removed 2 5417)
# Info    : It. 35000 - 29577 nodes created - worst tet radius 1.04097 (nodes removed 2 5421)
# Info    : It. 35500 - 30077 nodes created - worst tet radius 1.03564 (nodes removed 2 5421)
# Info    : It. 36000 - 30574 nodes created - worst tet radius 1.03014 (nodes removed 2 5424)
# Info    : It. 36500 - 31071 nodes created - worst tet radius 1.02435 (nodes removed 2 5427)
# Info    : It. 37000 - 31565 nodes created - worst tet radius 1.01875 (nodes removed 2 5433)
# Info    : It. 37500 - 32058 nodes created - worst tet radius 1.01364 (nodes removed 2 5440)
# Info    : It. 38000 - 32557 nodes created - worst tet radius 1.00816 (nodes removed 2 5441)
# Info    : It. 38500 - 33055 nodes created - worst tet radius 1.00321 (nodes removed 2 5443)
# Info    : 3D refinement terminated (49758 nodes total):
# Info    :  - 2598 Delaunay cavities modified for star shapeness
# Info    :  - 5445 nodes could not be inserted
# Info    :  - 266400 tetrahedra created in 3.28293 sec. (81146 tets/s)
# Info    : 59 node relocations
# Info    : Done meshing 3D (Wall 7.45902s, CPU 7.45854s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 0.002) with worst = 0.00168568 / average = 0.748344:
# Info    : 0.00 < quality < 0.10 :       693 elements
# Info    : 0.10 < quality < 0.20 :      2046 elements
# Info    : 0.20 < quality < 0.30 :      4092 elements
# Info    : 0.30 < quality < 0.40 :      7147 elements
# Info    : 0.40 < quality < 0.50 :     10245 elements
# Info    : 0.50 < quality < 0.60 :     20392 elements
# Info    : 0.60 < quality < 0.70 :     36161 elements
# Info    : 0.70 < quality < 0.80 :     58669 elements
# Info    : 0.80 < quality < 0.90 :     83710 elements
# Info    : 0.90 < quality < 1.00 :     43245 elements
# Info    : 6035 edge swaps, 742 node relocations (volume = 0.002): worst = 0.00922743 / average = 0.761871 (Wall 0.314541s, CPU 0.315554s)
# Info    : 6265 edge swaps, 811 node relocations (volume = 0.002): worst = 0.0928029 / average = 0.762342 (Wall 0.439949s, CPU 0.441342s)
# Info    : 6286 edge swaps, 828 node relocations (volume = 0.002): worst = 0.134801 / average = 0.762368 (Wall 0.551744s, CPU 0.553941s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :        14 elements
# Info    : 0.20 < quality < 0.30 :       178 elements
# Info    : 0.30 < quality < 0.40 :      7170 elements
# Info    : 0.40 < quality < 0.50 :     10300 elements
# Info    : 0.50 < quality < 0.60 :     20355 elements
# Info    : 0.60 < quality < 0.70 :     35967 elements
# Info    : 0.70 < quality < 0.80 :     59645 elements
# Info    : 0.80 < quality < 0.90 :     84590 elements
# Info    : 0.90 < quality < 1.00 :     43157 elements
# Info    : Done optimizing mesh (Wall 1.25747s, CPU 1.2307s)
# Info    : 49635 nodes 292744 elements
# Info    : Done reading 'BoxMesh.geo'
# [stdout:1] Info    : Reading 'BoxMesh.geo'...
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000899306s, CPU 0.001208s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Transfinite)
# Info    : [ 20%] Meshing surface 2 (Transfinite)
# Info    : [ 40%] Meshing surface 3 (Transfinite)
# Info    : [ 60%] Meshing surface 4 (Transfinite)
# Info    : [ 70%] Meshing surface 5 (Transfinite)
# Info    : [ 90%] Meshing surface 6 (Transfinite)
# Info    : Done meshing 2D (Wall 0.00349982s, CPU 0.003715s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 1 volume with 1 connected component
# Info    : Tetrahedrizing 15368 nodes...
# Info    : Done tetrahedrizing 15376 nodes (Wall 0.281354s, CPU 0.281928s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 1006 Steiner points
# Info    : Done reconstructing mesh (Wall 1.71136s, CPU 1.71338s)
# Info    : Found volume 1
# Info    : It. 0 - 0 nodes created - worst tet radius 66.6495 (nodes removed 0 0)
# Info    : It. 500 - 21 nodes created - worst tet radius 36.9203 (nodes removed 0 479)
# Info    : It. 1000 - 61 nodes created - worst tet radius 16.0699 (nodes removed 0 939)
# Info    : It. 1500 - 117 nodes created - worst tet radius 18.1194 (nodes removed 0 1383)
# Info    : It. 2000 - 194 nodes created - worst tet radius 8.00763 (nodes removed 0 1806)
# Info    : It. 2500 - 278 nodes created - worst tet radius 6.73154 (nodes removed 0 2222)
# Info    : It. 3000 - 395 nodes created - worst tet radius 5.70927 (nodes removed 0 2605)
# Info    : It. 3500 - 542 nodes created - worst tet radius 4.82412 (nodes removed 0 2958)
# Info    : It. 4000 - 713 nodes created - worst tet radius 4.18385 (nodes removed 0 3287)
# Info    : It. 4500 - 929 nodes created - worst tet radius 3.67671 (nodes removed 0 3571)
# Info    : It. 5000 - 1215 nodes created - worst tet radius 3.22497 (nodes removed 0 3785)
# Info    : It. 5500 - 1500 nodes created - worst tet radius 2.93348 (nodes removed 0 4000)
# Info    : It. 6000 - 1803 nodes created - worst tet radius 3.60032 (nodes removed 0 4197)
# Info    : It. 6500 - 2172 nodes created - worst tet radius 2.54046 (nodes removed 0 4328)
# Info    : It. 7000 - 2562 nodes created - worst tet radius 2.39587 (nodes removed 0 4438)
# Info    : It. 7500 - 2955 nodes created - worst tet radius 2.27172 (nodes removed 0 4545)
# Info    : It. 8000 - 3366 nodes created - worst tet radius 2.16224 (nodes removed 0 4634)
# Info    : It. 8500 - 3792 nodes created - worst tet radius 2.07477 (nodes removed 1 4707)
# Info    : 0.20 < quality < 0.30 :      4092 elements
# Info    : 0.30 < quality < 0.40 :      7147 elements
# Info    : 0.40 < quality < 0.50 :     10245 elements
# Info    : 0.50 < quality < 0.60 :     20392 elements
# Info    : 0.60 < quality < 0.70 :     36161 elements
# Info    : 0.70 < quality < 0.80 :     58669 elements
# Info    : 0.80 < quality < 0.90 :     83710 elements
# Info    : 0.90 < quality < 1.00 :     43245 elements
# Info    : 6035 edge swaps, 742 node relocations (volume = 0.002): worst = 0.00922743 / average = 0.761871 (Wall 0.366647s, CPU 0.367277s)
# Info    : 6265 edge swaps, 811 node relocations (volume = 0.002): worst = 0.0928029 / average = 0.762342 (Wall 0.465539s, CPU 0.466543s)
# Info    : 6286 edge swaps, 828 node relocations (volume = 0.002): worst = 0.134801 / average = 0.762368 (Wall 0.567001s, CPU 0.568095s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :        14 elements
# Info    : 0.20 < quality < 0.30 :       178 elements
# Info    : 0.30 < quality < 0.40 :      7170 elements
# Info    : 0.40 < quality < 0.50 :     10300 elements
# Info    : 0.50 < quality < 0.60 :     20355 elements
# Info    : 0.60 < quality < 0.70 :     35967 elements
# Info    : 0.70 < quality < 0.80 :     59645 elements
# Info    : 0.80 < quality < 0.90 :     84590 elements
# Info    : 0.90 < quality < 1.00 :     43157 elements
# Info    : Done optimizing mesh (Wall 1.39485s, CPU 1.38763s)
# Info    : 49635 nodes 292744 elements
# Info    : Done reading 'BoxMesh.geo'
# [stdout:8] Info    : Reading 'BoxMesh.geo'...
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000896106s, CPU 0.001194s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Transfinite)
# Info    : [ 20%] Meshing surface 2 (Transfinite)
# Info    : [ 40%] Meshing surface 3 (Transfinite)
# Info    : [ 60%] Meshing surface 4 (Transfinite)
# Info    : [ 70%] Meshing surface 5 (Transfinite)
# Info    : [ 90%] Meshing surface 6 (Transfinite)
# Info    : Done meshing 2D (Wall 0.00287742s, CPU 0.003072s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 1 volume with 1 connected component
# Info    : Tetrahedrizing 15368 nodes...
# Info    : Done tetrahedrizing 15376 nodes (Wall 0.30193s, CPU 0.292467s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 1006 Steiner points
# Info    : Done reconstructing mesh (Wall 1.79138s, CPU 1.78419s)
# Info    : Found volume 1
# Info    : It. 0 - 0 nodes created - worst tet radius 66.6495 (nodes removed 0 0)
# Info    : It. 500 - 21 nodes created - worst tet radius 36.9203 (nodes removed 0 479)
# Info    : It. 38500 - 33055 nodes created - worst tet radius 1.00321 (nodes removed 2 5443)
# Info    : 3D refinement terminated (49758 nodes total):
# Info    :  - 2598 Delaunay cavities modified for star shapeness
# Info    :  - 5445 nodes could not be inserted
# Info    :  - 266400 tetrahedra created in 3.37659 sec. (78896 tets/s)
# Info    : 59 node relocations
# Info    : Done meshing 3D (Wall 7.95119s, CPU 7.9715s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 0.002) with worst = 0.00168568 / average = 0.748344:
# Info    : 0.00 < quality < 0.10 :       693 elements
# Info    : 0.10 < quality < 0.20 :      2046 elements
# Info    : 0.20 < quality < 0.30 :      4092 elements
# Info    : 0.30 < quality < 0.40 :      7147 elements
# Info    : 0.40 < quality < 0.50 :     10245 elements
# Info    : 0.50 < quality < 0.60 :     20392 elements
# Info    : 0.60 < quality < 0.70 :     36161 elements
# Info    : 0.70 < quality < 0.80 :     58669 elements
# Info    : 0.80 < quality < 0.90 :     83710 elements
# Info    : 0.90 < quality < 1.00 :     43245 elements
# Info    : 6035 edge swaps, 742 node relocations (volume = 0.002): worst = 0.00922743 / average = 0.761871 (Wall 0.346199s, CPU 0.347119s)
# Info    : 6265 edge swaps, 811 node relocations (volume = 0.002): worst = 0.0928029 / average = 0.762342 (Wall 0.46381s, CPU 0.465084s)
# Info    : 6286 edge swaps, 828 node relocations (volume = 0.002): worst = 0.134801 / average = 0.762368 (Wall 0.559082s, CPU 0.560963s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :        14 elements
# Info    : 0.20 < quality < 0.30 :       178 elements
# Info    : 0.30 < quality < 0.40 :      7170 elements
# Info    : 0.40 < quality < 0.50 :     10300 elements
# Info    : 0.50 < quality < 0.60 :     20355 elements
# Info    : 0.60 < quality < 0.70 :     35967 elements
# Info    : 0.70 < quality < 0.80 :     59645 elements
# Info    : 0.80 < quality < 0.90 :     84590 elements
# Info    : 0.90 < quality < 1.00 :     43157 elements
# Info    : Done optimizing mesh (Wall 1.36477s, CPU 1.33792s)
# Info    : 49635 nodes 292744 elements
# Info    : Done reading 'BoxMesh.geo'
# [stdout:7] Info    : Reading 'BoxMesh.geo'...
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000854105s, CPU 0.001181s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Transfinite)
# Info    : [ 20%] Meshing surface 2 (Transfinite)
# Info    : [ 40%] Meshing surface 3 (Transfinite)
# Info    : [ 60%] Meshing surface 4 (Transfinite)
# Info    : [ 70%] Meshing surface 5 (Transfinite)
# Info    : [ 90%] Meshing surface 6 (Transfinite)
)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :        14 elements
# Info    : 0.20 < quality < 0.30 :       178 elements
# Info    : 0.30 < quality < 0.40 :      7170 elements
# Info    : 0.40 < quality < 0.50 :     10300 elements
# Info    : 0.50 < quality < 0.60 :     20355 elements
# Info    : 0.60 < quality < 0.70 :     35967 elements
# Info    : 0.70 < quality < 0.80 :     59645 elements
# Info    : 0.80 < quality < 0.90 :     84590 elements
# Info    : 0.90 < quality < 1.00 :     43157 elements
# Info    : Done optimizing mesh (Wall 1.42321s, CPU 1.40632s)
# Info    : 49635 nodes 292744 elements
# Info    : Done reading 'BoxMesh.geo'
# %px:   0%|          | 0/9 [00:00<?, ?tasks/s]
# [stderr:5] Warning : Boolean fragments skipped - too few arguments
# [stderr:2] Warning : Boolean fragments skipped - too few arguments
# [stderr:1] Warning : Boolean fragments skipped - too few arguments
# [stderr:0] Warning : Boolean fragments skipped - too few arguments
# [stderr:6] Warning : Boolean fragments skipped - too few arguments
# [stderr:3] Warning : Boolean fragments skipped - too few arguments
# [stderr:4] Warning : Boolean fragments skipped - too few arguments
# [stderr:8] Warning : Boolean fragments skipped - too few arguments
# [stderr:7] Warning : Boolean fragments skipped - too few arguments

# %%
# %%px
#
#
# import pyvista as pv
# from dolfinx.graph import partitioner_scotch
#
# #partitioner = dolfinx.mesh.create_cell_partitioner(partitioner_scotch())
#
# umesh.topology.create_connectivity(umesh.topology.dim-1, umesh.topology.dim)

# %%
# %%px
#
#
# import petsc4py
# import sys
# petsc4py.init(sys.argv)
# from petsc4py import PETSc
# from dolfinx.fem import (Constant,  Function, functionspace, assemble_scalar,
#                          dirichletbc, form, locate_dofs_topological, Function)
# from dolfinx.mesh import create_unit_square, locate_entities, meshtags
# from ufl import (FacetNormal, Measure, SpatialCoordinate, TestFunction, TrialFunction,
#                  div, dot, dx, grad, inner, lhs, rhs, system)
# import pyvista
# from dolfinx.plot import vtk_mesh
# import dolfinx.fem.petsc as petsc
# from dolfinx.geometry import bb_tree, compute_colliding_cells, compute_collisions_points

# %%
# %%px
#
#
# V = fem.functionspace(umesh, ("Lagrange", 1))
# fdim = umesh.topology.dim - 1
#
# top_marker, bottom_marker, sides_marker = 13, 14, 15
#
# print(len(ucell_tags.values))
# Out:
# [stdout:3] 30757
# [stdout:1] 30751
# [stdout:4] 31277
# [stdout:8] 30628
# [stdout:6] 30563
# [stdout:0] 30822
# [stdout:2] 30568
# [stdout:7] 30539
# [stdout:5] 31178

# %% [markdown]
# # from Jokken's tutorial: https://jsdokken.com/dolfinx-tutorial/chapter3/robin_neumann_dirichlet.html
# # 1: sides
# # 2: heatplate
# # 3: laser
# boundaries = [(1, lambda x: np.isclose(x[0], 0.0) | np.isclose(x[0], 1.0) | np.isclose(x[1], 0.0) | np.isclose(x[1], 1.0)),
#               (2, lambda x: np.isclose(x[2], 0.0)),
#               (3, lambda x: np.isclose(x[2], z_max))]
#
# facet_indices, facet_markers = [], []
# fdim = umesh.topology.dim - 1
# for (marker, locator) in boundaries:
#     facets = locate_entities(msh, fdim, locator)
#     facet_indices.append(facets)
#     facet_markers.append(np.full_like(facets, marker))
# facet_indices = np.hstack(facet_indices).astype(np.int32)
# facet_markers = np.hstack(facet_markers).astype(np.int32)
# sorted_facets = np.argsort(facet_indices)
# facet_tag = meshtags(umesh, fdim, facet_indices[sorted_facets], facet_markers[sorted_facets])

# %%
# %%px
#
#
# #create custom ds for where Neumann BC needs to be applied
# ds = Measure("ds", domain=umesh, subdomain_data=ufacet_tags)
# #ds_old = Measure("ds", domain=msh, subdomain_data=facet_tag)

# %%
# %%px
#
# class Delta_t:
#     def __init__ (self, value_):
#         self.value = value_
#     def __call__(self):
#         return self.value

# %%
# %%px
#
#
# # let's go: transient heat equation
# time_smoothing_factor = 10 # controls how smeared out the heat source is in time
#
# # Define the problem parameters
# rho = Constant(umesh, 4700.0) #[kg/m^3]
# cp = Constant(umesh, 500.0) #[J/(kg*K)]
# k = Constant(umesh, 20.0) #[W/(m*K)]
# h_bulk_powder = 10.0 # [W/(m^2*K)]
# #q_laserpower = Constant(msh, 2000000.0) # [W/m^2]
# T_heatplate_ = Constant(umesh, 500.0) # [K]
# q_powder = Constant(umesh, h_bulk_powder * 300.0) # [W/m^2] where 300 is the temperature difference between powder and part
# T_initial = Constant(umesh, 600.0) # [K]
#
# v_laser = 1.0 # [m/s] https://www.sciencedirect.com/science/article/pii/S2238785424027923
# P_laser = 250 # [W]
# h_hatch_um = 100 # [um]
# h_hatch = h_hatch_um * 1e-6 # [m]
# t_interlayer = 10 # [s]
# spot_size_um = 70 # [um]
# spot_size = spot_size_um * 1e-6 # [m]
#
# n_layers_lumped = 1
#
# # -->
# n_hatches = 0.1/h_hatch
# length_hatch = 0.1 # [m]
# t_true = n_hatches * length_hatch / v_laser # [s]
# ved = P_laser/(v_laser * h_hatch * t_true)
#
# t_true_scanning = 0.1**2 / (h_hatch * v_laser) # [s]
# E_tot_layer = P_laser * t_true_scanning # [J]
# E_tot = n_layers_lumped * E_tot_layer # [J]
# t_tot = n_layers_lumped * (t_true + t_interlayer) # [s]
#
# q_laserpower = Constant(umesh, 1 / time_smoothing_factor * 4 * P_laser / (np.pi * spot_size**2)) # [W/m^2]
# t_per_layer = t_true_scanning + t_interlayer # [s]
# #print("t_per_layer", t_per_layer)
#
# t_spot = time_smoothing_factor * E_tot_layer * np.pi * spot_size**2 / (4 * P_laser * 0.1**2) # [s]
#
# t = 0.0
# #delta_t = Constant(umesh, t_spot) # [s]
# dt = t_spot / 10.0
# delta_t = Constant(umesh, dt) # [s]
# #delta_t = Delta_t(t_spot / 10.0) # [s]
# t_end = 140 # [s]
# n_timesteps = int(t_end/dt) + 1
# print("time per spot", t_spot)
# #print("q_laserpower", q_laserpower.value)
# #n_spots = 0.1**2/(np.pi * spot_size**2 / 4)
# #print("n_spots", n_spots)
# #n_spots2 = t_true_scanning/(t_spot / time_smoothing_factor)
# #print("n_spots2", n_spots2)
# Out:
# [stdout:0] time per spot 0.00038484510006474965
# [stdout:1] time per spot 0.00038484510006474965
# [stdout:4] time per spot 0.00038484510006474965
# [stdout:2] time per spot 0.00038484510006474965
# [stdout:6] time per spot 0.00038484510006474965
# [stdout:3] time per spot 0.00038484510006474965
# [stdout:5] time per spot 0.00038484510006474965
# [stdout:8] time per spot 0.00038484510006474965
# [stdout:7] time per spot 0.00038484510006474965

# %%
# %%px
#
# # class to update delta_t depending on the temp difference of a specific point (top surface)
# # if value changes more than threshold = 1%, delta_t is halved, up to a minimum of t_spot / 10.0
# # if value changes less than threshold = 1%, delta_t is doubled, up to a maximum of 0.1s
# class delta_t_scheduler:
#     def __init__(self, delta_t, min_delta_t = t_spot / 10.0, max_delta_t = 0.05, threshold = 0.01):
#         self.delta_t = delta_t
#         self.min_delta_t = min_delta_t
#         self.max_delta_t = max_delta_t
#         self.last_temp = T_initial.value
#         self.threshold = threshold
#
#     def update_delta_t(self, T):
#         if (np.abs(T - self.last_temp) / self.last_temp) > self.threshold:
#             delta_t = max(self.delta_t / 2, self.min_delta_t)
#         else:
#             delta_t = min(self.delta_t * 2, self.max_delta_t)
#
#         self.last_temp = T
#         self.delta_t = delta_t
#
#     def reset_delta_t(self, value = 0.0): # if no value is given, reset to min_delta_t
#         #print("resetting delta_t")
#         if value:
#             self.delta_t = max(min(value, self.max_delta_t), self.min_delta_t) # makes sure delta_t is within bounds
#         else:
#             self.delta_t = self.min_delta_t
#             self.last_temp = T_initial.value
#
# delta_t_scheduler = delta_t_scheduler(dt)

# %% [markdown]
# %%px
#
# class Delta_t2:
#     def __init__(self, min_delta_t = t_spot / 10.0, max_delta_t = 0.1, threshold = 0.01):
#         self.min_delta_t = min_delta_t
#         self.max_delta_t = max_delta_t
#         self.threshold = threshold
#         self.delta_t = min_delta_t
#         self.last_temp = T_initial.value
#
#     def __call__(self, t, T):
#         # check whether we are jumping out, over, or into laser cycle
#         cycle_index = int(t // t_per_layer)
#         if cycle_index < n_layers_lumped: # only enter here if we are still in the laser cycle
#             if ((t % t_per_layer > t_spot) & ((t + self.delta_t) % t_per_layer < t_spot)): # checks whether we are jumping into the middle of a short laser cycle (from outside of a laser cycle)
#                 self.delta_t = t_per_layer - (t % t_per_layer)
#
#             elif ((t % t_per_layer < t_spot) & ((t + self.delta_t % t_per_layer) >= t_spot)): # checks whether we are jumping out of a short laser cycle
#
#
#
#
#             dt = t_spot - t % t_per_layer
#             delta_t_scheduler.reset_delta_t(delta_t.value)
#             delta_t.value = delta_t_scheduler.delta_t
#             if delta_t.value != old_delta_t: flag_delta_t_changed = True
#             if rank_contains_cellid == MPI.COMM_WORLD.Get_rank(): print("would have jumped out of laser spot --> resetting; delta_t.value = ", delta_t.value)
#
#         elif (t % t_per_layer > ((t + delta_t.value) % t_per_layer)): # checks whether we are jumping over a short laser cycle
#             delta_t.value = t_per_layer - t % t_per_layer
#             delta_t_scheduler.reset_delta_t(delta_t.value)
#             delta_t.value = delta_t_scheduler.delta_t
#             if delta_t.value != old_delta_t: flag_delta_t_changed = True
#             if rank_contains_cellid == MPI.COMM_WORLD.Get_rank(): print("would have jumped over laser spot --> resetting; delta_t.value = ", delta_t.value)
#
#         elif (delta_t.value != old_delta_t): # checks whether delta_t has changed --> need to re-assemble
#             flag_delta_t_changed = True
#
#         else: flag_delta_t_changed = False

# %%
# %%px
#
# #print(delta_t.value)
# #delta_t_scheduler.update_delta_t(10.0)
# #delta_t.value = delta_t_scheduler.delta_t
# #print(delta_t.value)
# #print(delta_t_scheduler.last_temp)

# %%
# %%px
#
# # Define the test function and trial function
# T = TrialFunction(V)
# v = TestFunction(V)
# T_n = Function(V) # previous time step
# T_heatplate = Function(V) # heatplate temperature
# x = SpatialCoordinate(umesh)
# n = FacetNormal(umesh)
#
# # Define the variational problem
# F_list = []
#
# F1 = rho * cp * T * v * dx # goes into a
# F2 = delta_t.value * k * inner(grad(T), grad(v)) * dx # goes into a
# F3 = - rho * cp * T_n * v * dx # goes into L
#
# #F = F1+F2+F3+F4
#
# F_list.append(F1)
# F_list.append(F2)
# F_list.append(F3)
#
#
# #F = rho * cp * T * v * dx + delta_t * k * inner(grad(T), grad(v)) * dx - rho * cp * T_n * v * dx
#
# # define time-dependent BCs
# def T_heatplate_function(t):
#     if t >= 0.0:
#         return lambda x: T_heatplate_.value
#
# # Neumann BC depending on T
# def q_laser_function_old(t):
#     if ((t >= 5.0) & (t <= 15.0)) | (t >= 20.0):
#         return q_powder.value*dt
#     else: return -q_laserpower.value*dt
# #t=0.0
#
# def q_laser_function(t):
#     cycle_index = int(t // t_per_layer)
#
#     if cycle_index >= n_layers_lumped:
#         print("finished")
#         return q_powder.value
#
#     t_in_cycle = t % t_per_layer
#
#     if t_in_cycle < t_spot:
#         return -q_laserpower.value
#     else: return q_powder.value
#
# #for n_i in range(n_timesteps):
# #    t = n_i * delta_t.value
#     #print(q_laser_function(t) != q_laser_function(t-delta_t.value))
#         #print(q_laser_function(t))
# t=0.0
# #print(((t >= 5.0) & (t <= 15.0)) | ((t >= 20.0) & (t <= 30.0)))
# #print(q_laser_function(t) != q_laser_function(t-delta_t.value))
# #print(q_laser_function(t), q_laser_function(t-delta_t.value))

# %%
# %%px
#
# # We can now create a general boundary condition class.
# class BoundaryCondition():
#     def __init__(self, type, marker, values):
#         self._type = type
#         if type == "Dirichlet":
#             u_D = Function(V)
#             #u_D.interpolate(values)
#             u_D.x.array[:] = values  # Assign the provided values to the function
#             facets = ufacet_tags.find(marker)
#             dofs = locate_dofs_topological(V, fdim, facets)
#             self._bc = dirichletbc(u_D, dofs)
#         elif type == "Neumann":
#             self._bc = inner(values, v) * ds(marker)
#         elif type == "Robin":
#             self._bc = values[0] * inner(T-values[1], v)* ds(marker)
#         else:
#             raise TypeError("Unknown boundary condition: {0:s}".format(type))
#     @property
#     def bc(self):
#         return self._bc
#
#     @property
#     def type(self):
#         return self._type

# %% [markdown]
# tdim = msh.topology.dim
# fdim = tdim - 1
# x = msh.geometry.x
#
# # --- 2. Create necessary mesh connectivity ---
# msh.topology.create_connectivity(fdim, 0)
# facet_to_vertex = msh.topology.connectivity(fdim, 0)
#
# facet_areas_by_name = {}
#
# for name, marker in boundaries:
#     # Find facets matching this marker
#     facets = locate_entities(msh, fdim, marker)
#     areas = []
#
#     for facet in facets:
#         # Get vertex indices of the facet
#         offset = facet_to_vertex.offsets[facet]
#         end = facet_to_vertex.offsets[facet + 1]
#         vertex_indices = facet_to_vertex.array[offset:end]
#         coords = x[vertex_indices]
#
#         if coords.shape[0] != 4:
#             raise RuntimeError(f"Expected 4 vertices on a quad facet, got {coords.shape[0]}")
#
#         # Compute area using two triangles
#         v0, v1, v2, v3 = coords
#         a1 = 0.5 * np.linalg.norm(np.cross(v1 - v0, v2 - v0))
#         a2 = 0.5 * np.linalg.norm(np.cross(v2 - v0, v3 - v0))
#         area = a1 + a2
#         areas.append(area)
#
#     facet_areas_by_name[name] = np.array(areas)

# %%
# %%px
#
# # set BCs initially:
# boundary_conditions = [BoundaryCondition("Neumann", sides_marker, q_powder*delta_t.value), # sides; goes into L
#                        BoundaryCondition("Dirichlet", bottom_marker, T_heatplate_.value), # heatplate
#                        BoundaryCondition("Neumann", top_marker, q_laser_function(t)*delta_t.value) # laser; goes into L
#                        ]
# bcs = []
#
# for condition in boundary_conditions:
#         if condition.type == "Dirichlet":
#             bcs.append(condition.bc)
#         else:
#             F_list.append(condition.bc)
#
# # function for only Dirichlet BCs: OBSOLETE
# def set_dirichlet_bcs(t):
#     bcs_ = []
#     for bc_ in boundary_conditions:
#         if bc_.type == "Dirichlet":
#             bcs_.append(bc_.bc)
#     return bcs_
#
# # assemble the system
# F = sum(F_list)
#
# (a, L) = system(F)

# %%
# %%px
#
# compiled_a = fem.form(a)
# A = petsc.assemble_matrix(compiled_a, bcs=bcs)
# A.assemble()
# compiled_L = fem.form(L)
# b = fem.Function(V)
# b.x.array[:] = T_initial
# T_n.x.array[:] = T_initial
#
# bcs = set_dirichlet_bcs(t)
#
# solver = PETSc.KSP().create(umesh.comm)
# solver.setOperators(A)
# solver.setType("cg")
# pc = solver.getPC()
# pc.setType("jacobi")

# %%
# %%px
#
# print(b.x.array[:])
# Out:
# [stdout:0] [600. 600. 600. ... 600. 600. 600.]
# [stdout:7] [600. 600. 600. ... 600. 600. 600.]
# [stdout:2] [600. 600. 600. ... 600. 600. 600.]
# [stdout:3] [600. 600. 600. ... 600. 600. 600.]
# [stdout:5] [600. 600. 600. ... 600. 600. 600.]
# [stdout:4] [600. 600. 600. ... 600. 600. 600.]
# [stdout:6] [600. 600. 600. ... 600. 600. 600.]
# [stdout:1] [600. 600. 600. ... 600. 600. 600.]
# [stdout:8] [600. 600. 600. ... 600. 600. 600.]

# %%
# %%px
#
# def average_temperature_at_z(z_target, mesh, temperature_field):
#     # Extract the coordinates of all mesh points
#     coords = mesh.points
#
#     # Find indices of nodes with z coordinate close to z_target
#     z_values = coords[:, 2]  # Get the z-component of the points
#     z_mask = np.isclose(z_values, z_target, atol=1e-3)  # Choose a tolerance for "closeness"
#
#     # Extract temperatures at those points
#     temperatures_at_z = temperature_field[z_mask]
#
#     # Return the average temperature at those points
#     return np.mean(temperatures_at_z) if temperatures_at_z.size > 0 else np.nan

# %%
# %%px
#
# pyvista.start_xvfb(0.5)  # Start virtual framebuffer for plotting
# plotter = pyvista.Plotter()
# plotter.open_gif("u_time_mpi.gif")
#
# topology, cells, geometry = plot.vtk_mesh(V)
# uh = fem.Function(V)
# grid = pyvista.UnstructuredGrid(topology, cells, geometry)
# grid.point_data["uh"] = uh.x.array
#
# # Optional: Add time display (updates every frame)
# text_actor = plotter.add_text("Time: 0.0 s", font_size=14, position="lower_left")

# %%
# %%px
#
# viridis = plt.cm.get_cmap("viridis", 25)
# sargs = dict(
#     title_font_size=25,
#     label_font_size=20,
#     fmt="%.0f",
#     color="black",
#     position_x=0.1,
#     position_y=0.9,
#     width=0.8,
#     height=0.08,
# )

# %%
# %%px
#
# renderer = plotter.add_mesh(
#     grid,
#     show_edges=True,
#     lighting=False,
#     cmap=viridis,
#     scalar_bar_args=sargs,
#     clim=[0, 1000],
# )

# %%
# %%px
#
# plotter.view_isometric()
# plotter.camera.zoom(0.8)

# %%
# %%px
#
# x_probe = np.array([[0.05, 0.05, 0.2]])
#
# # Find which cell contains the point (do this only once if the mesh is static)
#
# tdim = umesh.topology.dim
# tree = bb_tree(umesh, tdim)
# candidates = compute_collisions_points(tree, x_probe)
# colliding_cells = compute_colliding_cells(umesh, candidates, x_probe)
# cell_ids = colliding_cells.array
#
# rank = MPI.COMM_WORLD.Get_rank()
#
#
# if len(cell_ids) > 0:
#     cell_id = cell_ids[0]  # Get the first (and only) cell ID
#     owns_it = True # true on only one rank
# else: owns_it = False
#
# local_rank_value = rank if owns_it else MPI.COMM_WORLD.Get_size()
#
# owning_rank = MPI.COMM_WORLD.allreduce(local_rank_value, op=MPI.MIN)
#
# if owning_rank < MPI.COMM_WORLD.Get_size():
#     rank_contains_cellid = rank if rank == owning_rank else None
#     rank_contains_cellid = MPI.COMM_WORLD.bcast(rank_contains_cellid, root=owning_rank)
# else:
#     rank_contains_cellid = None  # Nobody owns the cell

# %%
# %%px
#
# Tracker_solution_function = []
# Tracker_time = []
# Tracker_delta_t = []
# T_tracker = []
# #print(rank_contains_cellid)

# %% [markdown]
# start_time = time.time()
#
#
# for n_i in range(n_timesteps):
#     t = n_i * dt
#
#     if q_laser_function(t) != q_laser_function(t-delta_t.value):
#
#         F = sum(F_list[0:3]) + BoundaryCondition("Neumann", top_marker, q_laser_function(t)).bc
#         #F = sum(F_list[0:4]) # remove the laser power term from the system
#         (a, L) = system(F)
#         compiled_a = fem.form(a)
#         A = petsc.assemble_matrix(compiled_a, bcs=bcs)
#         A.assemble()
#         compiled_L = fem.form(L)
#         b = fem.Function(V)
#         bcs = set_dirichlet_bcs(t)
#
#     # assemble RHS
#     b.x.array[:] = 0.0
#     petsc.assemble_vector(b.x.petsc_vec, compiled_L)
#
#     # apply BCs
#     #bcs = set_dirichlet_bcs(t)
#     petsc.apply_lifting(b.x.petsc_vec, [compiled_a], [bcs])
#     b.x.scatter_reverse(la.InsertMode.add)
#     fem.petsc.set_bc(b.x.petsc_vec, bcs)
#
#     # Solve linear problem
#     solver.solve(b.x.petsc_vec, uh.x.petsc_vec)
#     uh.x.scatter_forward()
#
#     # Update Tn
#     T_n.x.array[:] = uh.x.array
#
#     #print temperature at point on side face at z=0.1:
#     value = uh.eval(x_probe, cell_id)
#     print(f"Time {t:.2f} s: T({x_probe}) = {value[0]:.3f} K")
#     #T_tracker[n_i] = value[0]
#
# end_time = time.time()
# print("It took", end_time - start_time, "s to solve the problem.")
#
# #plotter.show()

# %% [markdown]
# start_time = time.time()
# for n_i in range(n_timesteps):
#     t = n_i * delta_t.value
#
#     if t == 5.0:
#         F = sum(F_list[0:4])
#         (a, L) = system(F)
#         compiled_a = fem.form(a)
#         A = petsc.assemble_matrix(compiled_a, bcs=bcs)
#         A.assemble()
#         compiled_L = fem.form(L)
#         b = fem.Function(V)
#
#     # assemble RHS
#     b.x.array[:] = 0.0
#     petsc.assemble_vector(b.x.petsc_vec, compiled_L)
#
#     # apply BCs
#     bcs = set_dirichlet_bcs(t)
#     petsc.apply_lifting(b.x.petsc_vec, [compiled_a], [bcs])
#     b.x.scatter_reverse(la.InsertMode.add)
#     fem.petsc.set_bc(b.x.petsc_vec, bcs)
#
#     # Solve linear problem
#     solver.solve(b.x.petsc_vec, uh.x.petsc_vec)
#     uh.x.scatter_forward()
#
#     # Update Tn
#     T_n.x.array[:] = uh.x.array
#
# end_time = time.time()
# print(f"Time taken for {n_timesteps} time steps: {end_time - start_time:.2f} seconds")

# %%
# %%px
#
# start_time = time.time()
# print("Starting the time loop...")
#
# T_n.x.array[:] = T_initial
# old_delta_t = dt
# n_i = 0
# flag_delta_t_changed = False
#
# # plotting doesnt work, so neglecting for now
# #with dolfinx.io.XDMFFile(MPI.COMM_WORLD, "solution.xdmf", "w") as xdmf_file:
#     #xdmf_file.write_mesh(umesh)  # Write the mesh once to the XDMF file
#
# while t < t_end:
#     n_i += 1
#
#     cycle_index = int((t + dt) // t_per_layer)
#     t_in_cycle = t % t_per_layer
#     if len(Tracker_time) > 0:
#         t_in_cycle_earlier = Tracker_time[-1] % t_per_layer
#     else: t_in_cycle_earlier = 0.0
#     #print("laser: ", q_laser_function(t))
#     #print("dt: ", dt)
#
#     if cycle_index < n_layers_lumped: # only enter here if we are still in the laser cycle
#         if ((t_in_cycle > t_spot) & (((t + dt) % t_per_layer) < t_spot)): # checks whether we are jumping into the middle of a short laser cycle (from outside of a laser cycle)
#             dt = t_per_layer - t_in_cycle
#             delta_t_scheduler.reset_delta_t(dt) # need to update scheduler's internal data
#             dt = delta_t_scheduler.delta_t
#             if dt != old_delta_t: flag_delta_t_changed = True
#             if rank_contains_cellid == MPI.COMM_WORLD.Get_rank(): print("would have jumped into laser spot --> resetting; dt = ", dt)
#
#         elif ((t_in_cycle < t_spot) & ((t + delta_t.value) % t_per_layer > t_spot)): # checks whether we are jumping out of a short laser cycle --> neglecting since time steps are small enough
#             flag_delta_t_changed = True
#         #    delta_t.value = t_spot - t_in_cycle
#         #    delta_t_scheduler.reset_delta_t(delta_t.value)
#         #    delta_t.value = delta_t_scheduler.delta_t
#         #    if delta_t.value != old_delta_t: flag_delta_t_changed = True
#         #    if rank_contains_cellid == MPI.COMM_WORLD.Get_rank(): print("would have jumped out of laser spot --> resetting; delta_t.value = ", delta_t.value)
#
#         elif ((t_in_cycle > t_spot) & (((t + dt) % t_per_layer) < t_in_cycle)): # checks whether we are jumping over a short laser cycle
#             dt = t_per_layer - t_in_cycle
#             if rank_contains_cellid == MPI.COMM_WORLD.Get_rank(): print("would have jumped over laser spot --> resetting; dt = ", dt)
#             delta_t_scheduler.reset_delta_t(dt)
#             dt = delta_t_scheduler.delta_t
#             if dt != old_delta_t: flag_delta_t_changed = True
#         elif (t_in_cycle_earlier < t_spot and t_in_cycle >= t_spot) or (t_in_cycle_earlier >= t_spot and t_in_cycle < t_spot): # checks whether we are jumping into a new laser cycle
#             flag_delta_t_changed = True
#
#     if (dt != old_delta_t): # checks whether delta_t has changed --> need to re-assemble
#             flag_delta_t_changed = True
#     else: flag_delta_t_changed = False
#
#     flag_delta_t_changed = MPI.COMM_WORLD.bcast(flag_delta_t_changed, root=owning_rank) # send delta_t to all processes IMPORTANT
#
#     t += dt
#
#     #t_in_cycle_earlier = (t - old_delta_t) % t_per_layer
#
#     delta_t.value = dt
#     Tracker_time.append(t) # important: keep track of the true time that was used
#     Tracker_delta_t.append(dt)
#
#     dt = MPI.COMM_WORLD.bcast(dt, root=owning_rank) # send delta_t to all processes
#     delta_t.value = MPI.COMM_WORLD.bcast(delta_t.value, root=owning_rank) # send delta_t to all processes
#     t = MPI.COMM_WORLD.bcast(t, root=owning_rank) # send t to all processes
#
#     if n_i == 10:
#         flag_delta_t_changed = True
#
#     if ( # detect changes in laserpower
#         #t_in_cycle_earlier < t_spot and t_in_cycle >= t_spot  # scanning → interlayer
#         #or t_in_cycle_earlier >= t_spot and t_in_cycle < t_spot  # interlayer → scanning
#         #or t_in_cycle_earlier > t_in_cycle  # new layer (cycle reset)
#         flag_delta_t_changed == True # delta_t changed
#     ):
#         #dt = MPI.COMM_WORLD.bcast(dt, root=owning_rank) # send delta_t to all processes
#         #t = MPI.COMM_WORLD.bcast(t, root=owning_rank) # send t to all processes
#         #print("power changed")
#         F2 = delta_t.value * k * inner(grad(T), grad(v)) * dx # we need to update this since delta_t changes --> somehow doesn't do anything...
#         F_list[1] = F2
#
#         F = sum(F_list[0:3]) + BoundaryCondition("Neumann", top_marker, q_laser_function(t)*delta_t.value).bc
#         (a, L) = system(F)
#         compiled_a = fem.form(a)
#         A = petsc.assemble_matrix(compiled_a, bcs=bcs)
#         A.assemble()
#         compiled_L = fem.form(L)
#         b = fem.Function(V)
#         bcs = set_dirichlet_bcs(t)
#
#
#     # assemble RHS
#     #print("assembling")
#     b.x.array[:] = 0.0
#     petsc.assemble_vector(b.x.petsc_vec, compiled_L)
#
#     #b.ghostUpdate(addv=PETSc.InsertMode.ADD, mode=PETSc.ScatterMode.REVERSE)
#     #b.ghostUpdate(addv=PETSc.InsertMode.INSERT, mode=PETSc.ScatterMode.FORWARD)
#
#     # apply BCs
#     #bcs = set_dirichlet_bcs(t)
#     #print("applying bcs")
#     petsc.apply_lifting(b.x.petsc_vec, [compiled_a], [bcs])
#     b.x.scatter_reverse(la.InsertMode.add)
#     fem.petsc.set_bc(b.x.petsc_vec, bcs)
#
#     # Solve linear problem
#     #print("solving")
#     solver.solve(b.x.petsc_vec, uh.x.petsc_vec)
#     uh.x.scatter_forward()
#
#     # Update Tn
#     #print("updating T_n")
#     T_n.x.array[:] = uh.x.array
#
#     # write solution file
#     if int(t) % 10 == 0:
#         T_n.x.scatter_forward()
#         Tracker_solution_function.append(T_n.x.array.copy())
#
#         #warning: writing to file is EXTREMELY slow --> only use when needed
#         #xdmf_file.write_function(T_n, t)
#
#     # Update plotter
#     # Update time display
#     #print("updating plotter")
#         #text_actor.SetText(0, f"Time: {t:.2f} s")
#         #plotter.update_scalars(uh.x.array, render=False)
#         #plotter.write_frame()
#
#     #print temperature at point on side face at z=0.1:
#     #print("printing temperature at probe point")
#     if rank_contains_cellid == MPI.COMM_WORLD.Get_rank():
#         value = uh.eval(x_probe, cell_id)
#         print(f"Time {t:.6f} s: T({x_probe}) = {value[0]:.3f} K")
#         T_tracker.append(value[0])
#
#         # Update delta_t
#         old_delta_t = dt
#         delta_t_scheduler.update_delta_t(value[0])
#         dt = delta_t_scheduler.delta_t
#         print("n_i: ", n_i, "delta_t: ", dt)
#
#     #delta_t.value = MPI.COMM_WORLD.bcast(delta_t.value, root=owning_rank) # send delta_t to all processes
#
# end_time = time.time()
# print("It took", end_time - start_time, "s to solve the problem.")
#
# #plotter.show()
# plotter.close()  # Close the plotter when done
# #print(len(T_tracker))
# Out:
# [stdout:7] Starting the time loop...
# It took 19.58863115310669 s to solve the problem.
# [stdout:1] Starting the time loop...
# It took 19.58956241607666 s to solve the problem.
# [stdout:4] Starting the time loop...
# It took 19.58727765083313 s to solve the problem.
# [stdout:3] Starting the time loop...
# It took 19.587281703948975 s to solve the problem.
# [stdout:2] Starting the time loop...
# It took 19.586528539657593 s to solve the problem.
# [stdout:8] Starting the time loop...
# Time 0.000038 s: T([[0.05 0.05 0.2 ]]) = 699.233 K
# n_i:  1 delta_t:  3.8484510006474965e-05
# Time 0.000077 s: T([[0.05 0.05 0.2 ]]) = 798.433 K
# n_i:  2 delta_t:  3.8484510006474965e-05
# Time 0.000115 s: T([[0.05 0.05 0.2 ]]) = 897.598 K
# n_i:  3 delta_t:  3.8484510006474965e-05
# Time 0.000154 s: T([[0.05 0.05 0.2 ]]) = 996.726 K
# n_i:  4 delta_t:  3.8484510006474965e-05
# Time 0.000192 s: T([[0.05 0.05 0.2 ]]) = 1095.809 K
# n_i:  5 delta_t:  3.8484510006474965e-05
# Time 0.000231 s: T([[0.05 0.05 0.2 ]]) = 1194.858 K
# n_i:  6 delta_t:  3.8484510006474965e-05
# Time 0.000269 s: T([[0.05 0.05 0.2 ]]) = 1293.872 K
# n_i:  7 delta_t:  3.8484510006474965e-05
# Time 0.000308 s: T([[0.05 0.05 0.2 ]]) = 1392.853 K
# n_i:  8 delta_t:  3.8484510006474965e-05
# Time 0.000346 s: T([[0.05 0.05 0.2 ]]) = 1491.801 K
# n_i:  9 delta_t:  3.8484510006474965e-05
# Time 0.000385 s: T([[0.05 0.05 0.2 ]]) = 1491.493 K
# n_i:  10 delta_t:  7.696902001294993e-05
# Time 0.000462 s: T([[0.05 0.05 0.2 ]]) = 1491.186 K
# n_i:  11 delta_t:  0.00015393804002589986
# Time 0.000616 s: T([[0.05 0.05 0.2 ]]) = 1490.879 K
# n_i:  12 delta_t:  0.0003078760800517997
# Time 0.000924 s: T([[0.05 0.05 0.2 ]]) = 1490.573 K
# n_i:  13 delta_t:  0.0006157521601035994
# Time 0.001539 s: T([[0.05 0.05 0.2 ]]) = 1490.268 K
# n_i:  14 delta_t:  0.0012315043202071989
# Time 0.002771 s: T([[0.05 0.05 0.2 ]]) = 1489.962 K
# n_i:  15 delta_t:  0.0024630086404143978
# Time 0.005234 s: T([[0.05 0.05 0.2 ]]) = 1489.656 K
# n_i:  16 delta_t:  0.0049260172808287955
# Time 0.010160 s: T([[0.05 0.05 0.2 ]]) = 1489.348 K
# n_i:  17 delta_t:  0.009852034561657591
# Time 0.020012 s: T([[0.05 0.05 0.2 ]]) = 1489.034 K
# n_i:  18 delta_t:  0.019704069123315182
# Time 0.039716 s: T([[0.05 0.05 0.2 ]]) = 1488.710 K
# n_i:  19 delta_t:  0.039408138246630364
# Time 0.079124 s: T([[0.05 0.05 0.2 ]]) = 1488.363 K
# n_i:  20 delta_t:  0.05
# Time 0.129124 s: T([[0.05 0.05 0.2 ]]) = 1488.006 K
# n_i:  21 delta_t:  0.05
# Time 0.179124 s: T([[0.05 0.05 0.2 ]]) = 1487.651 K
# n_i:  22 delta_t:  0.05
# Time 0.229124 s: T([[0.05 0.05 0.2 ]]) = 1487.297 K
# n_i:  23 delta_t:  0.05
# Time 0.279124 s: T([[0.05 0.05 0.2 ]]) = 1486.946 K
# n_i:  24 delta_t:  0.05
# Time 0.329124 s: T([[0.05 0.05 0.2 ]]) = 1486.595 K
# n_i:  25 delta_t:  0.05
# Time 0.379124 s: T([[0.05 0.05 0.2 ]]) = 1486.246 K
# n_i:  26 delta_t:  0.05
# Time 0.429124 s: T([[0.05 0.05 0.2 ]]) = 1485.898 K
# n_i:  27 delta_t:  0.05
# Time 0.479124 s: T([[0.05 0.05 0.2 ]]) = 1485.551 K
# n_i:  28 delta_t:  0.05
# Time 0.529124 s: T([[0.05 0.05 0.2 ]]) = 1485.206 K
# n_i:  29 delta_t:  0.05
# Time 0.579124 s: T([[0.05 0.05 0.2 ]]) = 1484.861 K
# n_i:  30 delta_t:  0.05
# Time 0.629124 s: T([[0.05 0.05 0.2 ]]) = 1484.518 K
# n_i:  31 delta_t:  0.05
# Time 0.679124 s: T([[0.05 0.05 0.2 ]]) = 1484.175 K
# n_i:  32 delta_t:  0.05
# Time 0.729124 s: T([[0.05 0.05 0.2 ]]) = 1483.841 K
# n_i:  33 delta_t:  0.05
# Time 0.779124 s: T([[0.05 0.05 0.2 ]]) = 1483.507 K
# n_i:  34 delta_t:  0.05
# Time 0.829124 s: T([[0.05 0.05 0.2 ]]) = 1483.174 K
# n_i:  35 delta_t:  0.05
# Time 0.879124 s: T([[0.05 0.05 0.2 ]]) = 1482.842 K
# n_i:  36 delta_t:  0.05
# Time 0.929124 s: T([[0.05 0.05 0.2 ]]) = 1482.511 K
# n_i:  37 delta_t:  0.05
# Time 0.979124 s: T([[0.05 0.05 0.2 ]]) = 1482.180 K
# n_i:  38 delta_t:  0.05
# Time 1.029124 s: T([[0.05 0.05 0.2 ]]) = 1481.850 K
# n_i:  39 delta_t:  0.05
# Time 1.079124 s: T([[0.05 0.05 0.2 ]]) = 1481.521 K
# n_i:  40 delta_t:  0.05
# Time 1.129124 s: T([[0.05 0.05 0.2 ]]) = 1481.193 K
# n_i:  41 delta_t:  0.05
# Time 1.179124 s: T([[0.05 0.05 0.2 ]]) = 1480.865 K
# n_i:  42 delta_t:  0.05
# Time 1.229124 s: T([[0.05 0.05 0.2 ]]) = 1480.538 K
# n_i:  43 delta_t:  0.05
# Time 1.279124 s: T([[0.05 0.05 0.2 ]]) = 1480.211 K
# n_i:  44 delta_t:  0.05
# Time 1.329124 s: T([[0.05 0.05 0.2 ]]) = 1479.885 K
# n_i:  45 delta_t:  0.05
# Time 1.379124 s: T([[0.05 0.05 0.2 ]]) = 1479.560 K
# n_i:  46 delta_t:  0.05
# Time 1.429124 s: T([[0.05 0.05 0.2 ]]) = 1479.236 K
# n_i:  47 delta_t:  0.05
# Time 1.479124 s: T([[0.05 0.05 0.2 ]]) = 1478.912 K
# n_i:  48 delta_t:  0.05
# Time 1.529124 s: T([[0.05 0.05 0.2 ]]) = 1478.589 K
# n_i:  49 delta_t:  0.05
# Time 1.579124 s: T([[0.05 0.05 0.2 ]]) = 1478.267 K
# n_i:  50 delta_t:  0.05
# Time 1.629124 s: T([[0.05 0.05 0.2 ]]) = 1477.945 K
# n_i:  51 delta_t:  0.05
# Time 1.679124 s: T([[0.05 0.05 0.2 ]]) = 1477.624 K
# n_i:  52 delta_t:  0.05
# Time 1.729124 s: T([[0.05 0.05 0.2 ]]) = 1477.303 K
# n_i:  53 delta_t:  0.05
# Time 1.779124 s: T([[0.05 0.05 0.2 ]]) = 1476.984 K
# n_i:  54 delta_t:  0.05
# Time 1.829124 s: T([[0.05 0.05 0.2 ]]) = 1476.664 K
# n_i:  55 delta_t:  0.05
# Time 1.879124 s: T([[0.05 0.05 0.2 ]]) = 1476.346 K
# n_i:  56 delta_t:  0.05
# Time 1.929124 s: T([[0.05 0.05 0.2 ]]) = 1476.028 K
# n_i:  57 delta_t:  0.05
# Time 1.979124 s: T([[0.05 0.05 0.2 ]]) = 1475.711 K
# n_i:  58 delta_t:  0.05
# Time 2.029124 s: T([[0.05 0.05 0.2 ]]) = 1475.395 K
# n_i:  59 delta_t:  0.05
# Time 2.079124 s: T([[0.05 0.05 0.2 ]]) = 1475.079 K
# n_i:  60 delta_t:  0.05
# Time 2.129124 s: T([[0.05 0.05 0.2 ]]) = 1474.764 K
# n_i:  61 delta_t:  0.05
# Time 2.179124 s: T([[0.05 0.05 0.2 ]]) = 1474.449 K
# n_i:  62 delta_t:  0.05
# Time 2.229124 s: T([[0.05 0.05 0.2 ]]) = 1474.135 K
# n_i:  63 delta_t:  0.05
# Time 2.279124 s: T([[0.05 0.05 0.2 ]]) = 1473.822 K
# n_i:  64 delta_t:  0.05
# Time 2.329124 s: T([[0.05 0.05 0.2 ]]) = 1473.509 K
# n_i:  65 delta_t:  0.05
# Time 2.379124 s: T([[0.05 0.05 0.2 ]]) = 1473.197 K
# n_i:  66 delta_t:  0.05
# Time 2.429124 s: T([[0.05 0.05 0.2 ]]) = 1472.886 K
# n_i:  67 delta_t:  0.05
# Time 2.479124 s: T([[0.05 0.05 0.2 ]]) = 1472.575 K
# n_i:  68 delta_t:  0.05
# Time 2.529124 s: T([[0.05 0.05 0.2 ]]) = 1472.265 K
# n_i:  69 delta_t:  0.05
# Time 2.579124 s: T([[0.05 0.05 0.2 ]]) = 1471.956 K
# n_i:  70 delta_t:  0.05
# Time 2.629124 s: T([[0.05 0.05 0.2 ]]) = 1471.647 K
# n_i:  71 delta_t:  0.05
# Time 2.679124 s: T([[0.05 0.05 0.2 ]]) = 1471.339 K
# n_i:  72 delta_t:  0.05
# Time 2.729124 s: T([[0.05 0.05 0.2 ]]) = 1471.031 K
# n_i:  73 delta_t:  0.05
# Time 2.779124 s: T([[0.05 0.05 0.2 ]]) = 1470.724 K
# n_i:  74 delta_t:  0.05
# Time 2.829124 s: T([[0.05 0.05 0.2 ]]) = 1470.418 K
# n_i:  75 delta_t:  0.05
# Time 2.879124 s: T([[0.05 0.05 0.2 ]]) = 1470.112 K
# n_i:  76 delta_t:  0.05
# Time 2.929124 s: T([[0.05 0.05 0.2 ]]) = 1469.807 K
# n_i:  77 delta_t:  0.05
# Time 2.979124 s: T([[0.05 0.05 0.2 ]]) = 1469.502 K
# n_i:  78 delta_t:  0.05
# Time 3.029124 s: T([[0.05 0.05 0.2 ]]) = 1469.198 K
# n_i:  79 delta_t:  0.05
# Time 3.079124 s: T([[0.05 0.05 0.2 ]]) = 1468.895 K
# n_i:  80 delta_t:  0.05
# Time 3.129124 s: T([[0.05 0.05 0.2 ]]) = 1468.592 K
# n_i:  81 delta_t:  0.05
# Time 3.179124 s: T([[0.05 0.05 0.2 ]]) = 1468.290 K
# n_i:  82 delta_t:  0.05
# Time 3.229124 s: T([[0.05 0.05 0.2 ]]) = 1467.989 K
# n_i:  83 delta_t:  0.05
# Time 3.279124 s: T([[0.05 0.05 0.2 ]]) = 1467.688 K
# n_i:  84 delta_t:  0.05
# Time 3.329124 s: T([[0.05 0.05 0.2 ]]) = 1467.388 K
# n_i:  85 delta_t:  0.05
# Time 3.379124 s: T([[0.05 0.05 0.2 ]]) = 1467.088 K
# n_i:  86 delta_t:  0.05
# Time 3.429124 s: T([[0.05 0.05 0.2 ]]) = 1466.789 K
# n_i:  87 delta_t:  0.05
# Time 3.479124 s: T([[0.05 0.05 0.2 ]]) = 1466.490 K
# n_i:  88 delta_t:  0.05
# Time 3.529124 s: T([[0.05 0.05 0.2 ]]) = 1466.193 K
# n_i:  89 delta_t:  0.05
# Time 3.579124 s: T([[0.05 0.05 0.2 ]]) = 1465.895 K
# n_i:  90 delta_t:  0.05
# Time 3.629124 s: T([[0.05 0.05 0.2 ]]) = 1465.598 K
# n_i:  91 delta_t:  0.05
# Time 3.679124 s: T([[0.05 0.05 0.2 ]]) = 1465.302 K
# n_i:  92 delta_t:  0.05
# Time 3.729124 s: T([[0.05 0.05 0.2 ]]) = 1465.007 K
# n_i:  93 delta_t:  0.05
# Time 3.779124 s: T([[0.05 0.05 0.2 ]]) = 1464.712 K
# n_i:  94 delta_t:  0.05
# Time 3.829124 s: T([[0.05 0.05 0.2 ]]) = 1464.417 K
# n_i:  95 delta_t:  0.05
# Time 3.879124 s: T([[0.05 0.05 0.2 ]]) = 1464.124 K
# n_i:  96 delta_t:  0.05
# Time 3.929124 s: T([[0.05 0.05 0.2 ]]) = 1463.830 K
# n_i:  97 delta_t:  0.05
# Time 3.979124 s: T([[0.05 0.05 0.2 ]]) = 1463.538 K
# n_i:  98 delta_t:  0.05
# Time 4.029124 s: T([[0.05 0.05 0.2 ]]) = 1463.246 K
# n_i:  99 delta_t:  0.05
# Time 4.079124 s: T([[0.05 0.05 0.2 ]]) = 1462.954 K
# n_i:  100 delta_t:  0.05
# Time 4.129124 s: T([[0.05 0.05 0.2 ]]) = 1462.663 K
# n_i:  101 delta_t:  0.05
# Time 4.179124 s: T([[0.05 0.05 0.2 ]]) = 1462.373 K
# n_i:  102 delta_t:  0.05
# Time 4.229124 s: T([[0.05 0.05 0.2 ]]) = 1462.083 K
# n_i:  103 delta_t:  0.05
# Time 4.279124 s: T([[0.05 0.05 0.2 ]]) = 1461.794 K
# n_i:  104 delta_t:  0.05
# Time 4.329124 s: T([[0.05 0.05 0.2 ]]) = 1461.505 K
# n_i:  105 delta_t:  0.05
# Time 4.379124 s: T([[0.05 0.05 0.2 ]]) = 1461.217 K
# n_i:  106 delta_t:  0.05
# Time 4.429124 s: T([[0.05 0.05 0.2 ]]) = 1460.929 K
# n_i:  107 delta_t:  0.05
# Time 4.479124 s: T([[0.05 0.05 0.2 ]]) = 1460.642 K
# n_i:  108 delta_t:  0.05
# Time 4.529124 s: T([[0.05 0.05 0.2 ]]) = 1460.356 K
# n_i:  109 delta_t:  0.05
# Time 4.579124 s: T([[0.05 0.05 0.2 ]]) = 1460.070 K
# n_i:  110 delta_t:  0.05
# Time 4.629124 s: T([[0.05 0.05 0.2 ]]) = 1459.784 K
# n_i:  111 delta_t:  0.05
# Time 4.679124 s: T([[0.05 0.05 0.2 ]]) = 1459.500 K
# n_i:  112 delta_t:  0.05
# Time 4.729124 s: T([[0.05 0.05 0.2 ]]) = 1459.215 K
# n_i:  113 delta_t:  0.05
# Time 4.779124 s: T([[0.05 0.05 0.2 ]]) = 1458.932 K
# n_i:  114 delta_t:  0.05
# Time 4.829124 s: T([[0.05 0.05 0.2 ]]) = 1458.648 K
# n_i:  115 delta_t:  0.05
# Time 4.879124 s: T([[0.05 0.05 0.2 ]]) = 1458.366 K
# n_i:  116 delta_t:  0.05
# Time 4.929124 s: T([[0.05 0.05 0.2 ]]) = 1458.084 K
# n_i:  117 delta_t:  0.05
# Time 4.979124 s: T([[0.05 0.05 0.2 ]]) = 1457.802 K
# n_i:  118 delta_t:  0.05
# Time 5.029124 s: T([[0.05 0.05 0.2 ]]) = 1457.521 K
# n_i:  119 delta_t:  0.05
# Time 5.079124 s: T([[0.05 0.05 0.2 ]]) = 1457.241 K
# n_i:  120 delta_t:  0.05
# Time 5.129124 s: T([[0.05 0.05 0.2 ]]) = 1456.961 K
# n_i:  121 delta_t:  0.05
# Time 5.179124 s: T([[0.05 0.05 0.2 ]]) = 1456.681 K
# n_i:  122 delta_t:  0.05
# Time 5.229124 s: T([[0.05 0.05 0.2 ]]) = 1456.402 K
# n_i:  123 delta_t:  0.05
# Time 5.279124 s: T([[0.05 0.05 0.2 ]]) = 1456.124 K
# n_i:  124 delta_t:  0.05
# Time 5.329124 s: T([[0.05 0.05 0.2 ]]) = 1455.846 K
# n_i:  125 delta_t:  0.05
# Time 5.379124 s: T([[0.05 0.05 0.2 ]]) = 1455.569 K
# n_i:  126 delta_t:  0.05
# Time 5.429124 s: T([[0.05 0.05 0.2 ]]) = 1455.292 K
# n_i:  127 delta_t:  0.05
# Time 5.479124 s: T([[0.05 0.05 0.2 ]]) = 1455.016 K
# n_i:  128 delta_t:  0.05
# Time 5.529124 s: T([[0.05 0.05 0.2 ]]) = 1454.740 K
# n_i:  129 delta_t:  0.05
# Time 5.579124 s: T([[0.05 0.05 0.2 ]]) = 1454.465 K
# n_i:  130 delta_t:  0.05
# Time 5.629124 s: T([[0.05 0.05 0.2 ]]) = 1454.190 K
# n_i:  131 delta_t:  0.05
# Time 5.679124 s: T([[0.05 0.05 0.2 ]]) = 1453.916 K
# n_i:  132 delta_t:  0.05
# Time 5.729124 s: T([[0.05 0.05 0.2 ]]) = 1453.642 K
# n_i:  133 delta_t:  0.05
# Time 5.779124 s: T([[0.05 0.05 0.2 ]]) = 1453.369 K
# n_i:  134 delta_t:  0.05
# Time 5.829124 s: T([[0.05 0.05 0.2 ]]) = 1453.096 K
# n_i:  135 delta_t:  0.05
# Time 5.879124 s: T([[0.05 0.05 0.2 ]]) = 1452.824 K
# n_i:  136 delta_t:  0.05
# Time 5.929124 s: T([[0.05 0.05 0.2 ]]) = 1452.552 K
# n_i:  137 delta_t:  0.05
# Time 5.979124 s: T([[0.05 0.05 0.2 ]]) = 1452.281 K
# n_i:  138 delta_t:  0.05
# Time 6.029124 s: T([[0.05 0.05 0.2 ]]) = 1452.011 K
# n_i:  139 delta_t:  0.05
# Time 6.079124 s: T([[0.05 0.05 0.2 ]]) = 1451.741 K
# n_i:  140 delta_t:  0.05
# Time 6.129124 s: T([[0.05 0.05 0.2 ]]) = 1451.471 K
# n_i:  141 delta_t:  0.05
# Time 6.179124 s: T([[0.05 0.05 0.2 ]]) = 1451.202 K
# n_i:  142 delta_t:  0.05
# Time 6.229124 s: T([[0.05 0.05 0.2 ]]) = 1450.933 K
# n_i:  143 delta_t:  0.05
# Time 6.279124 s: T([[0.05 0.05 0.2 ]]) = 1450.665 K
# n_i:  144 delta_t:  0.05
# Time 6.329124 s: T([[0.05 0.05 0.2 ]]) = 1450.397 K
# n_i:  145 delta_t:  0.05
# Time 6.379124 s: T([[0.05 0.05 0.2 ]]) = 1450.130 K
# n_i:  146 delta_t:  0.05
# Time 6.429124 s: T([[0.05 0.05 0.2 ]]) = 1449.863 K
# n_i:  147 delta_t:  0.05
# Time 6.479124 s: T([[0.05 0.05 0.2 ]]) = 1449.597 K
# n_i:  148 delta_t:  0.05
# Time 6.529124 s: T([[0.05 0.05 0.2 ]]) = 1449.331 K
# n_i:  149 delta_t:  0.05
# Time 6.579124 s: T([[0.05 0.05 0.2 ]]) = 1449.066 K
# n_i:  150 delta_t:  0.05
# Time 6.629124 s: T([[0.05 0.05 0.2 ]]) = 1448.801 K
# n_i:  151 delta_t:  0.05
# Time 6.679124 s: T([[0.05 0.05 0.2 ]]) = 1448.537 K
# n_i:  152 delta_t:  0.05
# Time 6.729124 s: T([[0.05 0.05 0.2 ]]) = 1448.273 K
# n_i:  153 delta_t:  0.05
# Time 6.779124 s: T([[0.05 0.05 0.2 ]]) = 1448.010 K
# n_i:  154 delta_t:  0.05
# Time 6.829124 s: T([[0.05 0.05 0.2 ]]) = 1447.747 K
# n_i:  155 delta_t:  0.05
# Time 6.879124 s: T([[0.05 0.05 0.2 ]]) = 1447.485 K
# n_i:  156 delta_t:  0.05
# Time 6.929124 s: T([[0.05 0.05 0.2 ]]) = 1447.223 K
# n_i:  157 delta_t:  0.05
# Time 6.979124 s: T([[0.05 0.05 0.2 ]]) = 1446.962 K
# n_i:  158 delta_t:  0.05
# Time 7.029124 s: T([[0.05 0.05 0.2 ]]) = 1446.701 K
# n_i:  159 delta_t:  0.05
# Time 7.079124 s: T([[0.05 0.05 0.2 ]]) = 1446.440 K
# n_i:  160 delta_t:  0.05
# Time 7.129124 s: T([[0.05 0.05 0.2 ]]) = 1446.180 K
# n_i:  161 delta_t:  0.05
# Time 7.179124 s: T([[0.05 0.05 0.2 ]]) = 1445.921 K
# n_i:  162 delta_t:  0.05
# Time 7.229124 s: T([[0.05 0.05 0.2 ]]) = 1445.662 K
# n_i:  163 delta_t:  0.05
# Time 7.279124 s: T([[0.05 0.05 0.2 ]]) = 1445.403 K
# n_i:  164 delta_t:  0.05
# Time 7.329124 s: T([[0.05 0.05 0.2 ]]) = 1445.145 K
# n_i:  165 delta_t:  0.05
# Time 7.379124 s: T([[0.05 0.05 0.2 ]]) = 1444.887 K
# n_i:  166 delta_t:  0.05
# Time 7.429124 s: T([[0.05 0.05 0.2 ]]) = 1444.630 K
# n_i:  167 delta_t:  0.05
# Time 7.479124 s: T([[0.05 0.05 0.2 ]]) = 1444.373 K
# n_i:  168 delta_t:  0.05
# Time 7.529124 s: T([[0.05 0.05 0.2 ]]) = 1444.117 K
# n_i:  169 delta_t:  0.05
# Time 7.579124 s: T([[0.05 0.05 0.2 ]]) = 1443.861 K
# n_i:  170 delta_t:  0.05
# Time 7.629124 s: T([[0.05 0.05 0.2 ]]) = 1443.606 K
# n_i:  171 delta_t:  0.05
# Time 7.679124 s: T([[0.05 0.05 0.2 ]]) = 1443.351 K
# n_i:  172 delta_t:  0.05
# Time 7.729124 s: T([[0.05 0.05 0.2 ]]) = 1443.096 K
# n_i:  173 delta_t:  0.05
# Time 7.779124 s: T([[0.05 0.05 0.2 ]]) = 1442.842 K
# n_i:  174 delta_t:  0.05
# Time 7.829124 s: T([[0.05 0.05 0.2 ]]) = 1442.589 K
# n_i:  175 delta_t:  0.05
# Time 7.879124 s: T([[0.05 0.05 0.2 ]]) = 1442.335 K
# n_i:  176 delta_t:  0.05
# Time 7.929124 s: T([[0.05 0.05 0.2 ]]) = 1442.083 K
# n_i:  177 delta_t:  0.05
# Time 7.979124 s: T([[0.05 0.05 0.2 ]]) = 1441.830 K
# n_i:  178 delta_t:  0.05
# Time 8.029124 s: T([[0.05 0.05 0.2 ]]) = 1441.578 K
# n_i:  179 delta_t:  0.05
# Time 8.079124 s: T([[0.05 0.05 0.2 ]]) = 1441.327 K
# n_i:  180 delta_t:  0.05
# Time 8.129124 s: T([[0.05 0.05 0.2 ]]) = 1441.076 K
# n_i:  181 delta_t:  0.05
# Time 8.179124 s: T([[0.05 0.05 0.2 ]]) = 1440.826 K
# n_i:  182 delta_t:  0.05
# Time 8.229124 s: T([[0.05 0.05 0.2 ]]) = 1440.575 K
# n_i:  183 delta_t:  0.05
# Time 8.279124 s: T([[0.05 0.05 0.2 ]]) = 1440.326 K
# n_i:  184 delta_t:  0.05
# Time 8.329124 s: T([[0.05 0.05 0.2 ]]) = 1440.077 K
# n_i:  185 delta_t:  0.05
# Time 8.379124 s: T([[0.05 0.05 0.2 ]]) = 1439.828 K
# n_i:  186 delta_t:  0.05
# Time 8.429124 s: T([[0.05 0.05 0.2 ]]) = 1439.579 K
# n_i:  187 delta_t:  0.05
# Time 8.479124 s: T([[0.05 0.05 0.2 ]]) = 1439.331 K
# n_i:  188 delta_t:  0.05
# Time 8.529124 s: T([[0.05 0.05 0.2 ]]) = 1439.084 K
# n_i:  189 delta_t:  0.05
# Time 8.579124 s: T([[0.05 0.05 0.2 ]]) = 1438.837 K
# n_i:  190 delta_t:  0.05
# Time 8.629124 s: T([[0.05 0.05 0.2 ]]) = 1438.590 K
# n_i:  191 delta_t:  0.05
# Time 8.679124 s: T([[0.05 0.05 0.2 ]]) = 1438.344 K
# n_i:  192 delta_t:  0.05
# Time 8.729124 s: T([[0.05 0.05 0.2 ]]) = 1438.098 K
# n_i:  193 delta_t:  0.05
# Time 8.779124 s: T([[0.05 0.05 0.2 ]]) = 1437.853 K
# n_i:  194 delta_t:  0.05
# Time 8.829124 s: T([[0.05 0.05 0.2 ]]) = 1437.608 K
# n_i:  195 delta_t:  0.05
# Time 8.879124 s: T([[0.05 0.05 0.2 ]]) = 1437.363 K
# n_i:  196 delta_t:  0.05
# Time 8.929124 s: T([[0.05 0.05 0.2 ]]) = 1437.119 K
# n_i:  197 delta_t:  0.05
# Time 8.979124 s: T([[0.05 0.05 0.2 ]]) = 1436.875 K
# n_i:  198 delta_t:  0.05
# Time 9.029124 s: T([[0.05 0.05 0.2 ]]) = 1436.632 K
# n_i:  199 delta_t:  0.05
# Time 9.079124 s: T([[0.05 0.05 0.2 ]]) = 1436.389 K
# n_i:  200 delta_t:  0.05
# Time 9.129124 s: T([[0.05 0.05 0.2 ]]) = 1436.146 K
# n_i:  201 delta_t:  0.05
# Time 9.179124 s: T([[0.05 0.05 0.2 ]]) = 1435.904 K
# n_i:  202 delta_t:  0.05
# Time 9.229124 s: T([[0.05 0.05 0.2 ]]) = 1435.663 K
# n_i:  203 delta_t:  0.05
# Time 9.279124 s: T([[0.05 0.05 0.2 ]]) = 1435.421 K
# n_i:  204 delta_t:  0.05
# Time 9.329124 s: T([[0.05 0.05 0.2 ]]) = 1435.180 K
# n_i:  205 delta_t:  0.05
# Time 9.379124 s: T([[0.05 0.05 0.2 ]]) = 1434.940 K
# n_i:  206 delta_t:  0.05
# Time 9.429124 s: T([[0.05 0.05 0.2 ]]) = 1434.700 K
# n_i:  207 delta_t:  0.05
# Time 9.479124 s: T([[0.05 0.05 0.2 ]]) = 1434.460 K
# n_i:  208 delta_t:  0.05
# Time 9.529124 s: T([[0.05 0.05 0.2 ]]) = 1434.221 K
# n_i:  209 delta_t:  0.05
# Time 9.579124 s: T([[0.05 0.05 0.2 ]]) = 1433.982 K
# n_i:  210 delta_t:  0.05
# Time 9.629124 s: T([[0.05 0.05 0.2 ]]) = 1433.744 K
# n_i:  211 delta_t:  0.05
# Time 9.679124 s: T([[0.05 0.05 0.2 ]]) = 1433.505 K
# n_i:  212 delta_t:  0.05
# Time 9.729124 s: T([[0.05 0.05 0.2 ]]) = 1433.268 K
# n_i:  213 delta_t:  0.05
# Time 9.779124 s: T([[0.05 0.05 0.2 ]]) = 1433.030 K
# n_i:  214 delta_t:  0.05
# Time 9.829124 s: T([[0.05 0.05 0.2 ]]) = 1432.793 K
# n_i:  215 delta_t:  0.05
# Time 9.879124 s: T([[0.05 0.05 0.2 ]]) = 1432.557 K
# n_i:  216 delta_t:  0.05
# Time 9.929124 s: T([[0.05 0.05 0.2 ]]) = 1432.321 K
# n_i:  217 delta_t:  0.05
# Time 9.979124 s: T([[0.05 0.05 0.2 ]]) = 1432.085 K
# n_i:  218 delta_t:  0.05
# Time 10.029124 s: T([[0.05 0.05 0.2 ]]) = 1431.850 K
# n_i:  219 delta_t:  0.05
# Time 10.079124 s: T([[0.05 0.05 0.2 ]]) = 1431.615 K
# n_i:  220 delta_t:  0.05
# Time 10.129124 s: T([[0.05 0.05 0.2 ]]) = 1431.380 K
# n_i:  221 delta_t:  0.05
# Time 10.179124 s: T([[0.05 0.05 0.2 ]]) = 1431.146 K
# n_i:  222 delta_t:  0.05
# Time 10.229124 s: T([[0.05 0.05 0.2 ]]) = 1430.912 K
# n_i:  223 delta_t:  0.05
# Time 10.279124 s: T([[0.05 0.05 0.2 ]]) = 1430.679 K
# n_i:  224 delta_t:  0.05
# Time 10.329124 s: T([[0.05 0.05 0.2 ]]) = 1430.445 K
# n_i:  225 delta_t:  0.05
# Time 10.379124 s: T([[0.05 0.05 0.2 ]]) = 1430.213 K
# n_i:  226 delta_t:  0.05
# Time 10.429124 s: T([[0.05 0.05 0.2 ]]) = 1429.980 K
# n_i:  227 delta_t:  0.05
# Time 10.479124 s: T([[0.05 0.05 0.2 ]]) = 1429.748 K
# n_i:  228 delta_t:  0.05
# Time 10.529124 s: T([[0.05 0.05 0.2 ]]) = 1429.517 K
# n_i:  229 delta_t:  0.05
# Time 10.579124 s: T([[0.05 0.05 0.2 ]]) = 1429.286 K
# n_i:  230 delta_t:  0.05
# Time 10.629124 s: T([[0.05 0.05 0.2 ]]) = 1429.055 K
# n_i:  231 delta_t:  0.05
# Time 10.679124 s: T([[0.05 0.05 0.2 ]]) = 1428.824 K
# n_i:  232 delta_t:  0.05
# Time 10.729124 s: T([[0.05 0.05 0.2 ]]) = 1428.594 K
# n_i:  233 delta_t:  0.05
# Time 10.779124 s: T([[0.05 0.05 0.2 ]]) = 1428.364 K
# n_i:  234 delta_t:  0.05
# Time 10.829124 s: T([[0.05 0.05 0.2 ]]) = 1428.135 K
# n_i:  235 delta_t:  0.05
# Time 10.879124 s: T([[0.05 0.05 0.2 ]]) = 1427.906 K
# n_i:  236 delta_t:  0.05
# Time 10.929124 s: T([[0.05 0.05 0.2 ]]) = 1427.677 K
# n_i:  237 delta_t:  0.05
# Time 10.979124 s: T([[0.05 0.05 0.2 ]]) = 1427.449 K
# n_i:  238 delta_t:  0.05
# Time 11.029124 s: T([[0.05 0.05 0.2 ]]) = 1427.221 K
# n_i:  239 delta_t:  0.05
# Time 11.079124 s: T([[0.05 0.05 0.2 ]]) = 1426.994 K
# n_i:  240 delta_t:  0.05
# Time 11.129124 s: T([[0.05 0.05 0.2 ]]) = 1426.766 K
# n_i:  241 delta_t:  0.05
# Time 11.179124 s: T([[0.05 0.05 0.2 ]]) = 1426.539 K
# n_i:  242 delta_t:  0.05
# Time 11.229124 s: T([[0.05 0.05 0.2 ]]) = 1426.313 K
# n_i:  243 delta_t:  0.05
# Time 11.279124 s: T([[0.05 0.05 0.2 ]]) = 1426.087 K
# n_i:  244 delta_t:  0.05
# Time 11.329124 s: T([[0.05 0.05 0.2 ]]) = 1425.861 K
# n_i:  245 delta_t:  0.05
# Time 11.379124 s: T([[0.05 0.05 0.2 ]]) = 1425.636 K
# n_i:  246 delta_t:  0.05
# Time 11.429124 s: T([[0.05 0.05 0.2 ]]) = 1425.411 K
# n_i:  247 delta_t:  0.05
# Time 11.479124 s: T([[0.05 0.05 0.2 ]]) = 1425.186 K
# n_i:  248 delta_t:  0.05
# Time 11.529124 s: T([[0.05 0.05 0.2 ]]) = 1424.961 K
# n_i:  249 delta_t:  0.05
# Time 11.579124 s: T([[0.05 0.05 0.2 ]]) = 1424.737 K
# n_i:  250 delta_t:  0.05
# Time 11.629124 s: T([[0.05 0.05 0.2 ]]) = 1424.514 K
# n_i:  251 delta_t:  0.05
# Time 11.679124 s: T([[0.05 0.05 0.2 ]]) = 1424.290 K
# n_i:  252 delta_t:  0.05
# Time 11.729124 s: T([[0.05 0.05 0.2 ]]) = 1424.067 K
# n_i:  253 delta_t:  0.05
# Time 11.779124 s: T([[0.05 0.05 0.2 ]]) = 1423.845 K
# n_i:  254 delta_t:  0.05
# Time 11.829124 s: T([[0.05 0.05 0.2 ]]) = 1423.622 K
# n_i:  255 delta_t:  0.05
# Time 11.879124 s: T([[0.05 0.05 0.2 ]]) = 1423.400 K
# n_i:  256 delta_t:  0.05
# Time 11.929124 s: T([[0.05 0.05 0.2 ]]) = 1423.179 K
# n_i:  257 delta_t:  0.05
# Time 11.979124 s: T([[0.05 0.05 0.2 ]]) = 1422.957 K
# n_i:  258 delta_t:  0.05
# Time 12.029124 s: T([[0.05 0.05 0.2 ]]) = 1422.736 K
# n_i:  259 delta_t:  0.05
# Time 12.079124 s: T([[0.05 0.05 0.2 ]]) = 1422.516 K
# n_i:  260 delta_t:  0.05
# Time 12.129124 s: T([[0.05 0.05 0.2 ]]) = 1422.295 K
# n_i:  261 delta_t:  0.05
# Time 12.179124 s: T([[0.05 0.05 0.2 ]]) = 1422.075 K
# n_i:  262 delta_t:  0.05
# Time 12.229124 s: T([[0.05 0.05 0.2 ]]) = 1421.856 K
# n_i:  263 delta_t:  0.05
# Time 12.279124 s: T([[0.05 0.05 0.2 ]]) = 1421.636 K
# n_i:  264 delta_t:  0.05
# Time 12.329124 s: T([[0.05 0.05 0.2 ]]) = 1421.417 K
# n_i:  265 delta_t:  0.05
# Time 12.379124 s: T([[0.05 0.05 0.2 ]]) = 1421.199 K
# n_i:  266 delta_t:  0.05
# Time 12.429124 s: T([[0.05 0.05 0.2 ]]) = 1420.981 K
# n_i:  267 delta_t:  0.05
# Time 12.479124 s: T([[0.05 0.05 0.2 ]]) = 1420.763 K
# n_i:  268 delta_t:  0.05
# Time 12.529124 s: T([[0.05 0.05 0.2 ]]) = 1420.545 K
# n_i:  269 delta_t:  0.05
# Time 12.579124 s: T([[0.05 0.05 0.2 ]]) = 1420.328 K
# n_i:  270 delta_t:  0.05
# Time 12.629124 s: T([[0.05 0.05 0.2 ]]) = 1420.111 K
# n_i:  271 delta_t:  0.05
# Time 12.679124 s: T([[0.05 0.05 0.2 ]]) = 1419.894 K
# n_i:  272 delta_t:  0.05
# Time 12.729124 s: T([[0.05 0.05 0.2 ]]) = 1419.677 K
# n_i:  273 delta_t:  0.05
# Time 12.779124 s: T([[0.05 0.05 0.2 ]]) = 1419.461 K
# n_i:  274 delta_t:  0.05
# Time 12.829124 s: T([[0.05 0.05 0.2 ]]) = 1419.246 K
# n_i:  275 delta_t:  0.05
# Time 12.879124 s: T([[0.05 0.05 0.2 ]]) = 1419.030 K
# n_i:  276 delta_t:  0.05
# Time 12.929124 s: T([[0.05 0.05 0.2 ]]) = 1418.815 K
# n_i:  277 delta_t:  0.05
# Time 12.979124 s: T([[0.05 0.05 0.2 ]]) = 1418.600 K
# n_i:  278 delta_t:  0.05
# Time 13.029124 s: T([[0.05 0.05 0.2 ]]) = 1418.386 K
# n_i:  279 delta_t:  0.05
# Time 13.079124 s: T([[0.05 0.05 0.2 ]]) = 1418.172 K
# n_i:  280 delta_t:  0.05
# Time 13.129124 s: T([[0.05 0.05 0.2 ]]) = 1417.958 K
# n_i:  281 delta_t:  0.05
# Time 13.179124 s: T([[0.05 0.05 0.2 ]]) = 1417.744 K
# n_i:  282 delta_t:  0.05
# Time 13.229124 s: T([[0.05 0.05 0.2 ]]) = 1417.531 K
# n_i:  283 delta_t:  0.05
# Time 13.279124 s: T([[0.05 0.05 0.2 ]]) = 1417.318 K
# n_i:  284 delta_t:  0.05
# Time 13.329124 s: T([[0.05 0.05 0.2 ]]) = 1417.106 K
# n_i:  285 delta_t:  0.05
# Time 13.379124 s: T([[0.05 0.05 0.2 ]]) = 1416.893 K
# n_i:  286 delta_t:  0.05
# Time 13.429124 s: T([[0.05 0.05 0.2 ]]) = 1416.681 K
# n_i:  287 delta_t:  0.05
# Time 13.479124 s: T([[0.05 0.05 0.2 ]]) = 1416.470 K
# n_i:  288 delta_t:  0.05
# Time 13.529124 s: T([[0.05 0.05 0.2 ]]) = 1416.258 K
# n_i:  289 delta_t:  0.05
# Time 13.579124 s: T([[0.05 0.05 0.2 ]]) = 1416.047 K
# n_i:  290 delta_t:  0.05
# Time 13.629124 s: T([[0.05 0.05 0.2 ]]) = 1415.836 K
# n_i:  291 delta_t:  0.05
# Time 13.679124 s: T([[0.05 0.05 0.2 ]]) = 1415.626 K
# n_i:  292 delta_t:  0.05
# Time 13.729124 s: T([[0.05 0.05 0.2 ]]) = 1415.416 K
# n_i:  293 delta_t:  0.05
# Time 13.779124 s: T([[0.05 0.05 0.2 ]]) = 1415.206 K
# n_i:  294 delta_t:  0.05
# Time 13.829124 s: T([[0.05 0.05 0.2 ]]) = 1414.996 K
# n_i:  295 delta_t:  0.05
# Time 13.879124 s: T([[0.05 0.05 0.2 ]]) = 1414.787 K
# n_i:  296 delta_t:  0.05
# Time 13.929124 s: T([[0.05 0.05 0.2 ]]) = 1414.578 K
# n_i:  297 delta_t:  0.05
# Time 13.979124 s: T([[0.05 0.05 0.2 ]]) = 1414.369 K
# n_i:  298 delta_t:  0.05
# Time 14.029124 s: T([[0.05 0.05 0.2 ]]) = 1414.161 K
# n_i:  299 delta_t:  0.05
# Time 14.079124 s: T([[0.05 0.05 0.2 ]]) = 1413.953 K
# n_i:  300 delta_t:  0.05
# Time 14.129124 s: T([[0.05 0.05 0.2 ]]) = 1413.745 K
# n_i:  301 delta_t:  0.05
# Time 14.179124 s: T([[0.05 0.05 0.2 ]]) = 1413.537 K
# n_i:  302 delta_t:  0.05
# Time 14.229124 s: T([[0.05 0.05 0.2 ]]) = 1413.330 K
# n_i:  303 delta_t:  0.05
# Time 14.279124 s: T([[0.05 0.05 0.2 ]]) = 1413.123 K
# n_i:  304 delta_t:  0.05
# Time 14.329124 s: T([[0.05 0.05 0.2 ]]) = 1412.917 K
# n_i:  305 delta_t:  0.05
# Time 14.379124 s: T([[0.05 0.05 0.2 ]]) = 1412.710 K
# n_i:  306 delta_t:  0.05
# Time 14.429124 s: T([[0.05 0.05 0.2 ]]) = 1412.504 K
# n_i:  307 delta_t:  0.05
# Time 14.479124 s: T([[0.05 0.05 0.2 ]]) = 1412.298 K
# n_i:  308 delta_t:  0.05
# Time 14.529124 s: T([[0.05 0.05 0.2 ]]) = 1412.093 K
# n_i:  309 delta_t:  0.05
# Time 14.579124 s: T([[0.05 0.05 0.2 ]]) = 1411.888 K
# n_i:  310 delta_t:  0.05
# Time 14.629124 s: T([[0.05 0.05 0.2 ]]) = 1411.683 K
# n_i:  311 delta_t:  0.05
# Time 14.679124 s: T([[0.05 0.05 0.2 ]]) = 1411.478 K
# n_i:  312 delta_t:  0.05
# Time 14.729124 s: T([[0.05 0.05 0.2 ]]) = 1411.274 K
# n_i:  313 delta_t:  0.05
# Time 14.779124 s: T([[0.05 0.05 0.2 ]]) = 1411.070 K
# n_i:  314 delta_t:  0.05
# Time 14.829124 s: T([[0.05 0.05 0.2 ]]) = 1410.866 K
# n_i:  315 delta_t:  0.05
# Time 14.879124 s: T([[0.05 0.05 0.2 ]]) = 1410.662 K
# n_i:  316 delta_t:  0.05
# Time 14.929124 s: T([[0.05 0.05 0.2 ]]) = 1410.459 K
# n_i:  317 delta_t:  0.05
# Time 14.979124 s: T([[0.05 0.05 0.2 ]]) = 1410.256 K
# n_i:  318 delta_t:  0.05
# Time 15.029124 s: T([[0.05 0.05 0.2 ]]) = 1410.053 K
# n_i:  319 delta_t:  0.05
# Time 15.079124 s: T([[0.05 0.05 0.2 ]]) = 1409.851 K
# n_i:  320 delta_t:  0.05
# Time 15.129124 s: T([[0.05 0.05 0.2 ]]) = 1409.649 K
# n_i:  321 delta_t:  0.05
# Time 15.179124 s: T([[0.05 0.05 0.2 ]]) = 1409.447 K
# n_i:  322 delta_t:  0.05
# Time 15.229124 s: T([[0.05 0.05 0.2 ]]) = 1409.245 K
# n_i:  323 delta_t:  0.05
# Time 15.279124 s: T([[0.05 0.05 0.2 ]]) = 1409.044 K
# n_i:  324 delta_t:  0.05
# Time 15.329124 s: T([[0.05 0.05 0.2 ]]) = 1408.843 K
# n_i:  325 delta_t:  0.05
# Time 15.379124 s: T([[0.05 0.05 0.2 ]]) = 1408.642 K
# n_i:  326 delta_t:  0.05
# Time 15.429124 s: T([[0.05 0.05 0.2 ]]) = 1408.441 K
# n_i:  327 delta_t:  0.05
# Time 15.479124 s: T([[0.05 0.05 0.2 ]]) = 1408.241 K
# n_i:  328 delta_t:  0.05
# Time 15.529124 s: T([[0.05 0.05 0.2 ]]) = 1408.041 K
# n_i:  329 delta_t:  0.05
# Time 15.579124 s: T([[0.05 0.05 0.2 ]]) = 1407.841 K
# n_i:  330 delta_t:  0.05
# Time 15.629124 s: T([[0.05 0.05 0.2 ]]) = 1407.642 K
# n_i:  331 delta_t:  0.05
# Time 15.679124 s: T([[0.05 0.05 0.2 ]]) = 1407.442 K
# n_i:  332 delta_t:  0.05
# Time 15.729124 s: T([[0.05 0.05 0.2 ]]) = 1407.243 K
# n_i:  333 delta_t:  0.05
# Time 15.779124 s: T([[0.05 0.05 0.2 ]]) = 1407.045 K
# n_i:  334 delta_t:  0.05
# Time 15.829124 s: T([[0.05 0.05 0.2 ]]) = 1406.846 K
# n_i:  335 delta_t:  0.05
# Time 15.879124 s: T([[0.05 0.05 0.2 ]]) = 1406.648 K
# n_i:  336 delta_t:  0.05
# Time 15.929124 s: T([[0.05 0.05 0.2 ]]) = 1406.450 K
# n_i:  337 delta_t:  0.05
# Time 15.979124 s: T([[0.05 0.05 0.2 ]]) = 1406.252 K
# n_i:  338 delta_t:  0.05
# Time 16.029124 s: T([[0.05 0.05 0.2 ]]) = 1406.055 K
# n_i:  339 delta_t:  0.05
# Time 16.079124 s: T([[0.05 0.05 0.2 ]]) = 1405.858 K
# n_i:  340 delta_t:  0.05
# Time 16.129124 s: T([[0.05 0.05 0.2 ]]) = 1405.661 K
# n_i:  341 delta_t:  0.05
# Time 16.179124 s: T([[0.05 0.05 0.2 ]]) = 1405.464 K
# n_i:  342 delta_t:  0.05
# Time 16.229124 s: T([[0.05 0.05 0.2 ]]) = 1405.268 K
# n_i:  343 delta_t:  0.05
# Time 16.279124 s: T([[0.05 0.05 0.2 ]]) = 1405.072 K
# n_i:  344 delta_t:  0.05
# Time 16.329124 s: T([[0.05 0.05 0.2 ]]) = 1404.876 K
# n_i:  345 delta_t:  0.05
# Time 16.379124 s: T([[0.05 0.05 0.2 ]]) = 1404.680 K
# n_i:  346 delta_t:  0.05
# Time 16.429124 s: T([[0.05 0.05 0.2 ]]) = 1404.485 K
# n_i:  347 delta_t:  0.05
# Time 16.479124 s: T([[0.05 0.05 0.2 ]]) = 1404.290 K
# n_i:  348 delta_t:  0.05
# Time 16.529124 s: T([[0.05 0.05 0.2 ]]) = 1404.095 K
# n_i:  349 delta_t:  0.05
# Time 16.579124 s: T([[0.05 0.05 0.2 ]]) = 1403.900 K
# n_i:  350 delta_t:  0.05
# Time 16.629124 s: T([[0.05 0.05 0.2 ]]) = 1403.706 K
# n_i:  351 delta_t:  0.05
# Time 16.679124 s: T([[0.05 0.05 0.2 ]]) = 1403.511 K
# n_i:  352 delta_t:  0.05
# Time 16.729124 s: T([[0.05 0.05 0.2 ]]) = 1403.318 K
# n_i:  353 delta_t:  0.05
# Time 16.779124 s: T([[0.05 0.05 0.2 ]]) = 1403.124 K
# n_i:  354 delta_t:  0.05
# Time 16.829124 s: T([[0.05 0.05 0.2 ]]) = 1402.930 K
# n_i:  355 delta_t:  0.05
# Time 16.879124 s: T([[0.05 0.05 0.2 ]]) = 1402.737 K
# n_i:  356 delta_t:  0.05
# Time 16.929124 s: T([[0.05 0.05 0.2 ]]) = 1402.544 K
# n_i:  357 delta_t:  0.05
# Time 16.979124 s: T([[0.05 0.05 0.2 ]]) = 1402.352 K
# n_i:  358 delta_t:  0.05
# Time 17.029124 s: T([[0.05 0.05 0.2 ]]) = 1402.159 K
# n_i:  359 delta_t:  0.05
# Time 17.079124 s: T([[0.05 0.05 0.2 ]]) = 1401.967 K
# n_i:  360 delta_t:  0.05
# Time 17.129124 s: T([[0.05 0.05 0.2 ]]) = 1401.775 K
# n_i:  361 delta_t:  0.05
# Time 17.179124 s: T([[0.05 0.05 0.2 ]]) = 1401.583 K
# n_i:  362 delta_t:  0.05
# Time 17.229124 s: T([[0.05 0.05 0.2 ]]) = 1401.391 K
# n_i:  363 delta_t:  0.05
# Time 17.279124 s: T([[0.05 0.05 0.2 ]]) = 1401.200 K
# n_i:  364 delta_t:  0.05
# Time 17.329124 s: T([[0.05 0.05 0.2 ]]) = 1401.009 K
# n_i:  365 delta_t:  0.05
# Time 17.379124 s: T([[0.05 0.05 0.2 ]]) = 1400.818 K
# n_i:  366 delta_t:  0.05
# Time 17.429124 s: T([[0.05 0.05 0.2 ]]) = 1400.628 K
# n_i:  367 delta_t:  0.05
# Time 17.479124 s: T([[0.05 0.05 0.2 ]]) = 1400.437 K
# n_i:  368 delta_t:  0.05
# Time 17.529124 s: T([[0.05 0.05 0.2 ]]) = 1400.247 K
# n_i:  369 delta_t:  0.05
# Time 17.579124 s: T([[0.05 0.05 0.2 ]]) = 1400.057 K
# n_i:  370 delta_t:  0.05
# Time 17.629124 s: T([[0.05 0.05 0.2 ]]) = 1399.868 K
# n_i:  371 delta_t:  0.05
# Time 17.679124 s: T([[0.05 0.05 0.2 ]]) = 1399.678 K
# n_i:  372 delta_t:  0.05
# Time 17.729124 s: T([[0.05 0.05 0.2 ]]) = 1399.489 K
# n_i:  373 delta_t:  0.05
# Time 17.779124 s: T([[0.05 0.05 0.2 ]]) = 1399.300 K
# n_i:  374 delta_t:  0.05
# Time 17.829124 s: T([[0.05 0.05 0.2 ]]) = 1399.111 K
# n_i:  375 delta_t:  0.05
# Time 17.879124 s: T([[0.05 0.05 0.2 ]]) = 1398.923 K
# n_i:  376 delta_t:  0.05
# Time 17.929124 s: T([[0.05 0.05 0.2 ]]) = 1398.734 K
# n_i:  377 delta_t:  0.05
# Time 17.979124 s: T([[0.05 0.05 0.2 ]]) = 1398.546 K
# n_i:  378 delta_t:  0.05
# Time 18.029124 s: T([[0.05 0.05 0.2 ]]) = 1398.358 K
# n_i:  379 delta_t:  0.05
# Time 18.079124 s: T([[0.05 0.05 0.2 ]]) = 1398.171 K
# n_i:  380 delta_t:  0.05
# Time 18.129124 s: T([[0.05 0.05 0.2 ]]) = 1397.983 K
# n_i:  381 delta_t:  0.05
# Time 18.179124 s: T([[0.05 0.05 0.2 ]]) = 1397.796 K
# n_i:  382 delta_t:  0.05
# Time 18.229124 s: T([[0.05 0.05 0.2 ]]) = 1397.609 K
# n_i:  383 delta_t:  0.05
# Time 18.279124 s: T([[0.05 0.05 0.2 ]]) = 1397.422 K
# n_i:  384 delta_t:  0.05
# Time 18.329124 s: T([[0.05 0.05 0.2 ]]) = 1397.236 K
# n_i:  385 delta_t:  0.05
# Time 18.379124 s: T([[0.05 0.05 0.2 ]]) = 1397.050 K
# n_i:  386 delta_t:  0.05
# Time 18.429124 s: T([[0.05 0.05 0.2 ]]) = 1396.863 K
# n_i:  387 delta_t:  0.05
# Time 18.479124 s: T([[0.05 0.05 0.2 ]]) = 1396.678 K
# n_i:  388 delta_t:  0.05
# Time 18.529124 s: T([[0.05 0.05 0.2 ]]) = 1396.492 K
# n_i:  389 delta_t:  0.05
# Time 18.579124 s: T([[0.05 0.05 0.2 ]]) = 1396.306 K
# n_i:  390 delta_t:  0.05
# Time 18.629124 s: T([[0.05 0.05 0.2 ]]) = 1396.121 K
# n_i:  391 delta_t:  0.05
# Time 18.679124 s: T([[0.05 0.05 0.2 ]]) = 1395.936 K
# n_i:  392 delta_t:  0.05
# Time 18.729124 s: T([[0.05 0.05 0.2 ]]) = 1395.751 K
# n_i:  393 delta_t:  0.05
# Time 18.779124 s: T([[0.05 0.05 0.2 ]]) = 1395.567 K
# n_i:  394 delta_t:  0.05
# Time 18.829124 s: T([[0.05 0.05 0.2 ]]) = 1395.382 K
# n_i:  395 delta_t:  0.05
# Time 18.879124 s: T([[0.05 0.05 0.2 ]]) = 1395.198 K
# n_i:  396 delta_t:  0.05
# Time 18.929124 s: T([[0.05 0.05 0.2 ]]) = 1395.014 K
# n_i:  397 delta_t:  0.05
# Time 18.979124 s: T([[0.05 0.05 0.2 ]]) = 1394.830 K
# n_i:  398 delta_t:  0.05
# Time 19.029124 s: T([[0.05 0.05 0.2 ]]) = 1394.647 K
# n_i:  399 delta_t:  0.05
# Time 19.079124 s: T([[0.05 0.05 0.2 ]]) = 1394.463 K
# n_i:  400 delta_t:  0.05
# Time 19.129124 s: T([[0.05 0.05 0.2 ]]) = 1394.280 K
# n_i:  401 delta_t:  0.05
# Time 19.179124 s: T([[0.05 0.05 0.2 ]]) = 1394.097 K
# n_i:  402 delta_t:  0.05
# Time 19.229124 s: T([[0.05 0.05 0.2 ]]) = 1393.915 K
# n_i:  403 delta_t:  0.05
# Time 19.279124 s: T([[0.05 0.05 0.2 ]]) = 1393.732 K
# n_i:  404 delta_t:  0.05
# Time 19.329124 s: T([[0.05 0.05 0.2 ]]) = 1393.550 K
# n_i:  405 delta_t:  0.05
# Time 19.379124 s: T([[0.05 0.05 0.2 ]]) = 1393.368 K
# n_i:  406 delta_t:  0.05
# Time 19.429124 s: T([[0.05 0.05 0.2 ]]) = 1393.186 K
# n_i:  407 delta_t:  0.05
# Time 19.479124 s: T([[0.05 0.05 0.2 ]]) = 1393.004 K
# n_i:  408 delta_t:  0.05
# Time 19.529124 s: T([[0.05 0.05 0.2 ]]) = 1392.822 K
# n_i:  409 delta_t:  0.05
# Time 19.579124 s: T([[0.05 0.05 0.2 ]]) = 1392.641 K
# n_i:  410 delta_t:  0.05
# Time 19.629124 s: T([[0.05 0.05 0.2 ]]) = 1392.460 K
# n_i:  411 delta_t:  0.05
# Time 19.679124 s: T([[0.05 0.05 0.2 ]]) = 1392.279 K
# n_i:  412 delta_t:  0.05
# Time 19.729124 s: T([[0.05 0.05 0.2 ]]) = 1392.098 K
# n_i:  413 delta_t:  0.05
# Time 19.779124 s: T([[0.05 0.05 0.2 ]]) = 1391.918 K
# n_i:  414 delta_t:  0.05
# Time 19.829124 s: T([[0.05 0.05 0.2 ]]) = 1391.738 K
# n_i:  415 delta_t:  0.05
# Time 19.879124 s: T([[0.05 0.05 0.2 ]]) = 1391.557 K
# n_i:  416 delta_t:  0.05
# Time 19.929124 s: T([[0.05 0.05 0.2 ]]) = 1391.377 K
# n_i:  417 delta_t:  0.05
# Time 19.979124 s: T([[0.05 0.05 0.2 ]]) = 1391.198 K
# n_i:  418 delta_t:  0.05
# Time 20.029124 s: T([[0.05 0.05 0.2 ]]) = 1391.018 K
# n_i:  419 delta_t:  0.05
# Time 20.079124 s: T([[0.05 0.05 0.2 ]]) = 1390.839 K
# n_i:  420 delta_t:  0.05
# Time 20.129124 s: T([[0.05 0.05 0.2 ]]) = 1390.660 K
# n_i:  421 delta_t:  0.05
# Time 20.179124 s: T([[0.05 0.05 0.2 ]]) = 1390.481 K
# n_i:  422 delta_t:  0.05
# Time 20.229124 s: T([[0.05 0.05 0.2 ]]) = 1390.302 K
# n_i:  423 delta_t:  0.05
# Time 20.279124 s: T([[0.05 0.05 0.2 ]]) = 1390.123 K
# n_i:  424 delta_t:  0.05
# Time 20.329124 s: T([[0.05 0.05 0.2 ]]) = 1389.945 K
# n_i:  425 delta_t:  0.05
# Time 20.379124 s: T([[0.05 0.05 0.2 ]]) = 1389.767 K
# n_i:  426 delta_t:  0.05
# Time 20.429124 s: T([[0.05 0.05 0.2 ]]) = 1389.589 K
# n_i:  427 delta_t:  0.05
# Time 20.479124 s: T([[0.05 0.05 0.2 ]]) = 1389.411 K
# n_i:  428 delta_t:  0.05
# Time 20.529124 s: T([[0.05 0.05 0.2 ]]) = 1389.233 K
# n_i:  429 delta_t:  0.05
# Time 20.579124 s: T([[0.05 0.05 0.2 ]]) = 1389.056 K
# n_i:  430 delta_t:  0.05
# Time 20.629124 s: T([[0.05 0.05 0.2 ]]) = 1388.878 K
# n_i:  431 delta_t:  0.05
# Time 20.679124 s: T([[0.05 0.05 0.2 ]]) = 1388.701 K
# n_i:  432 delta_t:  0.05
# Time 20.729124 s: T([[0.05 0.05 0.2 ]]) = 1388.524 K
# n_i:  433 delta_t:  0.05
# Time 20.779124 s: T([[0.05 0.05 0.2 ]]) = 1388.348 K
# n_i:  434 delta_t:  0.05
# Time 20.829124 s: T([[0.05 0.05 0.2 ]]) = 1388.171 K
# n_i:  435 delta_t:  0.05
# Time 20.879124 s: T([[0.05 0.05 0.2 ]]) = 1387.995 K
# n_i:  436 delta_t:  0.05
# Time 20.929124 s: T([[0.05 0.05 0.2 ]]) = 1387.819 K
# n_i:  437 delta_t:  0.05
# Time 20.979124 s: T([[0.05 0.05 0.2 ]]) = 1387.643 K
# n_i:  438 delta_t:  0.05
# Time 21.029124 s: T([[0.05 0.05 0.2 ]]) = 1387.467 K
# n_i:  439 delta_t:  0.05
# Time 21.079124 s: T([[0.05 0.05 0.2 ]]) = 1387.291 K
# n_i:  440 delta_t:  0.05
# Time 21.129124 s: T([[0.05 0.05 0.2 ]]) = 1387.116 K
# n_i:  441 delta_t:  0.05
# Time 21.179124 s: T([[0.05 0.05 0.2 ]]) = 1386.941 K
# n_i:  442 delta_t:  0.05
# Time 21.229124 s: T([[0.05 0.05 0.2 ]]) = 1386.765 K
# n_i:  443 delta_t:  0.05
# Time 21.279124 s: T([[0.05 0.05 0.2 ]]) = 1386.591 K
# n_i:  444 delta_t:  0.05
# Time 21.329124 s: T([[0.05 0.05 0.2 ]]) = 1386.416 K
# n_i:  445 delta_t:  0.05
# Time 21.379124 s: T([[0.05 0.05 0.2 ]]) = 1386.241 K
# n_i:  446 delta_t:  0.05
# Time 21.429124 s: T([[0.05 0.05 0.2 ]]) = 1386.067 K
# n_i:  447 delta_t:  0.05
# Time 21.479124 s: T([[0.05 0.05 0.2 ]]) = 1385.893 K
# n_i:  448 delta_t:  0.05
# Time 21.529124 s: T([[0.05 0.05 0.2 ]]) = 1385.719 K
# n_i:  449 delta_t:  0.05
# Time 21.579124 s: T([[0.05 0.05 0.2 ]]) = 1385.545 K
# n_i:  450 delta_t:  0.05
# Time 21.629124 s: T([[0.05 0.05 0.2 ]]) = 1385.371 K
# n_i:  451 delta_t:  0.05
# Time 21.679124 s: T([[0.05 0.05 0.2 ]]) = 1385.198 K
# n_i:  452 delta_t:  0.05
# Time 21.729124 s: T([[0.05 0.05 0.2 ]]) = 1385.024 K
# n_i:  453 delta_t:  0.05
# Time 21.779124 s: T([[0.05 0.05 0.2 ]]) = 1384.851 K
# n_i:  454 delta_t:  0.05
# Time 21.829124 s: T([[0.05 0.05 0.2 ]]) = 1384.678 K
# n_i:  455 delta_t:  0.05
# Time 21.879124 s: T([[0.05 0.05 0.2 ]]) = 1384.505 K
# n_i:  456 delta_t:  0.05
# Time 21.929124 s: T([[0.05 0.05 0.2 ]]) = 1384.333 K
# n_i:  457 delta_t:  0.05
# Time 21.979124 s: T([[0.05 0.05 0.2 ]]) = 1384.160 K
# n_i:  458 delta_t:  0.05
# Time 22.029124 s: T([[0.05 0.05 0.2 ]]) = 1383.988 K
# n_i:  459 delta_t:  0.05
# Time 22.079124 s: T([[0.05 0.05 0.2 ]]) = 1383.816 K
# n_i:  460 delta_t:  0.05
# Time 22.129124 s: T([[0.05 0.05 0.2 ]]) = 1383.644 K
# n_i:  461 delta_t:  0.05
# Time 22.179124 s: T([[0.05 0.05 0.2 ]]) = 1383.472 K
# n_i:  462 delta_t:  0.05
# Time 22.229124 s: T([[0.05 0.05 0.2 ]]) = 1383.300 K
# n_i:  463 delta_t:  0.05
# Time 22.279124 s: T([[0.05 0.05 0.2 ]]) = 1383.129 K
# n_i:  464 delta_t:  0.05
# Time 22.329124 s: T([[0.05 0.05 0.2 ]]) = 1382.957 K
# n_i:  465 delta_t:  0.05
# Time 22.379124 s: T([[0.05 0.05 0.2 ]]) = 1382.786 K
# n_i:  466 delta_t:  0.05
# Time 22.429124 s: T([[0.05 0.05 0.2 ]]) = 1382.615 K
# n_i:  467 delta_t:  0.05
# Time 22.479124 s: T([[0.05 0.05 0.2 ]]) = 1382.444 K
# n_i:  468 delta_t:  0.05
# Time 22.529124 s: T([[0.05 0.05 0.2 ]]) = 1382.274 K
# n_i:  469 delta_t:  0.05
# Time 22.579124 s: T([[0.05 0.05 0.2 ]]) = 1382.103 K
# n_i:  470 delta_t:  0.05
# Time 22.629124 s: T([[0.05 0.05 0.2 ]]) = 1381.933 K
# n_i:  471 delta_t:  0.05
# Time 22.679124 s: T([[0.05 0.05 0.2 ]]) = 1381.763 K
# n_i:  472 delta_t:  0.05
# Time 22.729124 s: T([[0.05 0.05 0.2 ]]) = 1381.593 K
# n_i:  473 delta_t:  0.05
# Time 22.779124 s: T([[0.05 0.05 0.2 ]]) = 1381.423 K
# n_i:  474 delta_t:  0.05
# Time 22.829124 s: T([[0.05 0.05 0.2 ]]) = 1381.253 K
# n_i:  475 delta_t:  0.05
# Time 22.879124 s: T([[0.05 0.05 0.2 ]]) = 1381.083 K
# n_i:  476 delta_t:  0.05
# Time 22.929124 s: T([[0.05 0.05 0.2 ]]) = 1380.914 K
# n_i:  477 delta_t:  0.05
# Time 22.979124 s: T([[0.05 0.05 0.2 ]]) = 1380.745 K
# n_i:  478 delta_t:  0.05
# Time 23.029124 s: T([[0.05 0.05 0.2 ]]) = 1380.576 K
# n_i:  479 delta_t:  0.05
# Time 23.079124 s: T([[0.05 0.05 0.2 ]]) = 1380.407 K
# n_i:  480 delta_t:  0.05
# Time 23.129124 s: T([[0.05 0.05 0.2 ]]) = 1380.238 K
# n_i:  481 delta_t:  0.05
# Time 23.179124 s: T([[0.05 0.05 0.2 ]]) = 1380.069 K
# n_i:  482 delta_t:  0.05
# Time 23.229124 s: T([[0.05 0.05 0.2 ]]) = 1379.901 K
# n_i:  483 delta_t:  0.05
# Time 23.279124 s: T([[0.05 0.05 0.2 ]]) = 1379.733 K
# n_i:  484 delta_t:  0.05
# Time 23.329124 s: T([[0.05 0.05 0.2 ]]) = 1379.564 K
# n_i:  485 delta_t:  0.05
# Time 23.379124 s: T([[0.05 0.05 0.2 ]]) = 1379.397 K
# n_i:  486 delta_t:  0.05
# Time 23.429124 s: T([[0.05 0.05 0.2 ]]) = 1379.229 K
# n_i:  487 delta_t:  0.05
# Time 23.479124 s: T([[0.05 0.05 0.2 ]]) = 1379.061 K
# n_i:  488 delta_t:  0.05
# Time 23.529124 s: T([[0.05 0.05 0.2 ]]) = 1378.893 K
# n_i:  489 delta_t:  0.05
# Time 23.579124 s: T([[0.05 0.05 0.2 ]]) = 1378.726 K
# n_i:  490 delta_t:  0.05
# Time 23.629124 s: T([[0.05 0.05 0.2 ]]) = 1378.559 K
# n_i:  491 delta_t:  0.05
# Time 23.679124 s: T([[0.05 0.05 0.2 ]]) = 1378.392 K
# n_i:  492 delta_t:  0.05
# Time 23.729124 s: T([[0.05 0.05 0.2 ]]) = 1378.225 K
# n_i:  493 delta_t:  0.05
# Time 23.779124 s: T([[0.05 0.05 0.2 ]]) = 1378.058 K
# n_i:  494 delta_t:  0.05
# Time 23.829124 s: T([[0.05 0.05 0.2 ]]) = 1377.891 K
# n_i:  495 delta_t:  0.05
# Time 23.879124 s: T([[0.05 0.05 0.2 ]]) = 1377.725 K
# n_i:  496 delta_t:  0.05
# Time 23.929124 s: T([[0.05 0.05 0.2 ]]) = 1377.559 K
# n_i:  497 delta_t:  0.05
# Time 23.979124 s: T([[0.05 0.05 0.2 ]]) = 1377.392 K
# n_i:  498 delta_t:  0.05
# Time 24.029124 s: T([[0.05 0.05 0.2 ]]) = 1377.226 K
# n_i:  499 delta_t:  0.05
# Time 24.079124 s: T([[0.05 0.05 0.2 ]]) = 1377.060 K
# n_i:  500 delta_t:  0.05
# Time 24.129124 s: T([[0.05 0.05 0.2 ]]) = 1376.895 K
# n_i:  501 delta_t:  0.05
# Time 24.179124 s: T([[0.05 0.05 0.2 ]]) = 1376.729 K
# n_i:  502 delta_t:  0.05
# Time 24.229124 s: T([[0.05 0.05 0.2 ]]) = 1376.563 K
# n_i:  503 delta_t:  0.05
# Time 24.279124 s: T([[0.05 0.05 0.2 ]]) = 1376.398 K
# n_i:  504 delta_t:  0.05
# Time 24.329124 s: T([[0.05 0.05 0.2 ]]) = 1376.233 K
# n_i:  505 delta_t:  0.05
# Time 24.379124 s: T([[0.05 0.05 0.2 ]]) = 1376.068 K
# n_i:  506 delta_t:  0.05
# Time 24.429124 s: T([[0.05 0.05 0.2 ]]) = 1375.903 K
# n_i:  507 delta_t:  0.05
# Time 24.479124 s: T([[0.05 0.05 0.2 ]]) = 1375.738 K
# n_i:  508 delta_t:  0.05
# Time 24.529124 s: T([[0.05 0.05 0.2 ]]) = 1375.574 K
# n_i:  509 delta_t:  0.05
# Time 24.579124 s: T([[0.05 0.05 0.2 ]]) = 1375.409 K
# n_i:  510 delta_t:  0.05
# Time 24.629124 s: T([[0.05 0.05 0.2 ]]) = 1375.245 K
# n_i:  511 delta_t:  0.05
# Time 24.679124 s: T([[0.05 0.05 0.2 ]]) = 1375.081 K
# n_i:  512 delta_t:  0.05
# Time 24.729124 s: T([[0.05 0.05 0.2 ]]) = 1374.917 K
# n_i:  513 delta_t:  0.05
# Time 24.779124 s: T([[0.05 0.05 0.2 ]]) = 1374.753 K
# n_i:  514 delta_t:  0.05
# Time 24.829124 s: T([[0.05 0.05 0.2 ]]) = 1374.589 K
# n_i:  515 delta_t:  0.05
# Time 24.879124 s: T([[0.05 0.05 0.2 ]]) = 1374.425 K
# n_i:  516 delta_t:  0.05
# Time 24.929124 s: T([[0.05 0.05 0.2 ]]) = 1374.262 K
# n_i:  517 delta_t:  0.05
# Time 24.979124 s: T([[0.05 0.05 0.2 ]]) = 1374.098 K
# n_i:  518 delta_t:  0.05
# Time 25.029124 s: T([[0.05 0.05 0.2 ]]) = 1373.935 K
# n_i:  519 delta_t:  0.05
# Time 25.079124 s: T([[0.05 0.05 0.2 ]]) = 1373.772 K
# n_i:  520 delta_t:  0.05
# Time 25.129124 s: T([[0.05 0.05 0.2 ]]) = 1373.609 K
# n_i:  521 delta_t:  0.05
# Time 25.179124 s: T([[0.05 0.05 0.2 ]]) = 1373.446 K
# n_i:  522 delta_t:  0.05
# Time 25.229124 s: T([[0.05 0.05 0.2 ]]) = 1373.283 K
# n_i:  523 delta_t:  0.05
# Time 25.279124 s: T([[0.05 0.05 0.2 ]]) = 1373.121 K
# n_i:  524 delta_t:  0.05
# Time 25.329124 s: T([[0.05 0.05 0.2 ]]) = 1372.958 K
# n_i:  525 delta_t:  0.05
# Time 25.379124 s: T([[0.05 0.05 0.2 ]]) = 1372.796 K
# n_i:  526 delta_t:  0.05
# Time 25.429124 s: T([[0.05 0.05 0.2 ]]) = 1372.634 K
# n_i:  527 delta_t:  0.05
# Time 25.479124 s: T([[0.05 0.05 0.2 ]]) = 1372.472 K
# n_i:  528 delta_t:  0.05
# Time 25.529124 s: T([[0.05 0.05 0.2 ]]) = 1372.310 K
# n_i:  529 delta_t:  0.05
# Time 25.579124 s: T([[0.05 0.05 0.2 ]]) = 1372.148 K
# n_i:  530 delta_t:  0.05
# Time 25.629124 s: T([[0.05 0.05 0.2 ]]) = 1371.987 K
# n_i:  531 delta_t:  0.05
# Time 25.679124 s: T([[0.05 0.05 0.2 ]]) = 1371.825 K
# n_i:  532 delta_t:  0.05
# Time 25.729124 s: T([[0.05 0.05 0.2 ]]) = 1371.664 K
# n_i:  533 delta_t:  0.05
# Time 25.779124 s: T([[0.05 0.05 0.2 ]]) = 1371.502 K
# n_i:  534 delta_t:  0.05
# Time 25.829124 s: T([[0.05 0.05 0.2 ]]) = 1371.341 K
# n_i:  535 delta_t:  0.05
# Time 25.879124 s: T([[0.05 0.05 0.2 ]]) = 1371.180 K
# n_i:  536 delta_t:  0.05
# Time 25.929124 s: T([[0.05 0.05 0.2 ]]) = 1371.020 K
# n_i:  537 delta_t:  0.05
# Time 25.979124 s: T([[0.05 0.05 0.2 ]]) = 1370.859 K
# n_i:  538 delta_t:  0.05
# Time 26.029124 s: T([[0.05 0.05 0.2 ]]) = 1370.698 K
# n_i:  539 delta_t:  0.05
# Time 26.079124 s: T([[0.05 0.05 0.2 ]]) = 1370.538 K
# n_i:  540 delta_t:  0.05
# Time 26.129124 s: T([[0.05 0.05 0.2 ]]) = 1370.377 K
# n_i:  541 delta_t:  0.05
# Time 26.179124 s: T([[0.05 0.05 0.2 ]]) = 1370.217 K
# n_i:  542 delta_t:  0.05
# Time 26.229124 s: T([[0.05 0.05 0.2 ]]) = 1370.057 K
# n_i:  543 delta_t:  0.05
# Time 26.279124 s: T([[0.05 0.05 0.2 ]]) = 1369.897 K
# n_i:  544 delta_t:  0.05
# Time 26.329124 s: T([[0.05 0.05 0.2 ]]) = 1369.737 K
# n_i:  545 delta_t:  0.05
# Time 26.379124 s: T([[0.05 0.05 0.2 ]]) = 1369.577 K
# n_i:  546 delta_t:  0.05
# Time 26.429124 s: T([[0.05 0.05 0.2 ]]) = 1369.418 K
# n_i:  547 delta_t:  0.05
# Time 26.479124 s: T([[0.05 0.05 0.2 ]]) = 1369.258 K
# n_i:  548 delta_t:  0.05
# Time 26.529124 s: T([[0.05 0.05 0.2 ]]) = 1369.099 K
# n_i:  549 delta_t:  0.05
# Time 26.579124 s: T([[0.05 0.05 0.2 ]]) = 1368.940 K
# n_i:  550 delta_t:  0.05
# Time 26.629124 s: T([[0.05 0.05 0.2 ]]) = 1368.780 K
# n_i:  551 delta_t:  0.05
# Time 26.679124 s: T([[0.05 0.05 0.2 ]]) = 1368.621 K
# n_i:  552 delta_t:  0.05
# Time 26.729124 s: T([[0.05 0.05 0.2 ]]) = 1368.463 K
# n_i:  553 delta_t:  0.05
# Time 26.779124 s: T([[0.05 0.05 0.2 ]]) = 1368.304 K
# n_i:  554 delta_t:  0.05
# Time 26.829124 s: T([[0.05 0.05 0.2 ]]) = 1368.145 K
# n_i:  555 delta_t:  0.05
# Time 26.879124 s: T([[0.05 0.05 0.2 ]]) = 1367.987 K
# n_i:  556 delta_t:  0.05
# Time 26.929124 s: T([[0.05 0.05 0.2 ]]) = 1367.828 K
# n_i:  557 delta_t:  0.05
# Time 26.979124 s: T([[0.05 0.05 0.2 ]]) = 1367.670 K
# n_i:  558 delta_t:  0.05
# Time 27.029124 s: T([[0.05 0.05 0.2 ]]) = 1367.512 K
# n_i:  559 delta_t:  0.05
# Time 27.079124 s: T([[0.05 0.05 0.2 ]]) = 1367.354 K
# n_i:  560 delta_t:  0.05
# Time 27.129124 s: T([[0.05 0.05 0.2 ]]) = 1367.196 K
# n_i:  561 delta_t:  0.05
# Time 27.179124 s: T([[0.05 0.05 0.2 ]]) = 1367.038 K
# n_i:  562 delta_t:  0.05
# Time 27.229124 s: T([[0.05 0.05 0.2 ]]) = 1366.880 K
# n_i:  563 delta_t:  0.05
# Time 27.279124 s: T([[0.05 0.05 0.2 ]]) = 1366.722 K
# n_i:  564 delta_t:  0.05
# Time 27.329124 s: T([[0.05 0.05 0.2 ]]) = 1366.565 K
# n_i:  565 delta_t:  0.05
# Time 27.379124 s: T([[0.05 0.05 0.2 ]]) = 1366.408 K
# n_i:  566 delta_t:  0.05
# Time 27.429124 s: T([[0.05 0.05 0.2 ]]) = 1366.250 K
# n_i:  567 delta_t:  0.05
# Time 27.479124 s: T([[0.05 0.05 0.2 ]]) = 1366.093 K
# n_i:  568 delta_t:  0.05
# Time 27.529124 s: T([[0.05 0.05 0.2 ]]) = 1365.936 K
# n_i:  569 delta_t:  0.05
# Time 27.579124 s: T([[0.05 0.05 0.2 ]]) = 1365.779 K
# n_i:  570 delta_t:  0.05
# Time 27.629124 s: T([[0.05 0.05 0.2 ]]) = 1365.623 K
# n_i:  571 delta_t:  0.05
# Time 27.679124 s: T([[0.05 0.05 0.2 ]]) = 1365.466 K
# n_i:  572 delta_t:  0.05
# Time 27.729124 s: T([[0.05 0.05 0.2 ]]) = 1365.309 K
# n_i:  573 delta_t:  0.05
# Time 27.779124 s: T([[0.05 0.05 0.2 ]]) = 1365.153 K
# n_i:  574 delta_t:  0.05
# Time 27.829124 s: T([[0.05 0.05 0.2 ]]) = 1364.996 K
# n_i:  575 delta_t:  0.05
# Time 27.879124 s: T([[0.05 0.05 0.2 ]]) = 1364.840 K
# n_i:  576 delta_t:  0.05
# Time 27.929124 s: T([[0.05 0.05 0.2 ]]) = 1364.684 K
# n_i:  577 delta_t:  0.05
# Time 27.979124 s: T([[0.05 0.05 0.2 ]]) = 1364.528 K
# n_i:  578 delta_t:  0.05
# Time 28.029124 s: T([[0.05 0.05 0.2 ]]) = 1364.372 K
# n_i:  579 delta_t:  0.05
# Time 28.079124 s: T([[0.05 0.05 0.2 ]]) = 1364.216 K
# n_i:  580 delta_t:  0.05
# Time 28.129124 s: T([[0.05 0.05 0.2 ]]) = 1364.061 K
# n_i:  581 delta_t:  0.05
# Time 28.179124 s: T([[0.05 0.05 0.2 ]]) = 1363.905 K
# n_i:  582 delta_t:  0.05
# Time 28.229124 s: T([[0.05 0.05 0.2 ]]) = 1363.750 K
# n_i:  583 delta_t:  0.05
# Time 28.279124 s: T([[0.05 0.05 0.2 ]]) = 1363.594 K
# n_i:  584 delta_t:  0.05
# Time 28.329124 s: T([[0.05 0.05 0.2 ]]) = 1363.439 K
# n_i:  585 delta_t:  0.05
# Time 28.379124 s: T([[0.05 0.05 0.2 ]]) = 1363.284 K
# n_i:  586 delta_t:  0.05
# Time 28.429124 s: T([[0.05 0.05 0.2 ]]) = 1363.129 K
# n_i:  587 delta_t:  0.05
# Time 28.479124 s: T([[0.05 0.05 0.2 ]]) = 1362.974 K
# n_i:  588 delta_t:  0.05
# Time 28.529124 s: T([[0.05 0.05 0.2 ]]) = 1362.819 K
# n_i:  589 delta_t:  0.05
# Time 28.579124 s: T([[0.05 0.05 0.2 ]]) = 1362.664 K
# n_i:  590 delta_t:  0.05
# Time 28.629124 s: T([[0.05 0.05 0.2 ]]) = 1362.510 K
# n_i:  591 delta_t:  0.05
# Time 28.679124 s: T([[0.05 0.05 0.2 ]]) = 1362.355 K
# n_i:  592 delta_t:  0.05
# Time 28.729124 s: T([[0.05 0.05 0.2 ]]) = 1362.201 K
# n_i:  593 delta_t:  0.05
# Time 28.779124 s: T([[0.05 0.05 0.2 ]]) = 1362.046 K
# n_i:  594 delta_t:  0.05
# Time 28.829124 s: T([[0.05 0.05 0.2 ]]) = 1361.892 K
# n_i:  595 delta_t:  0.05
# Time 28.879124 s: T([[0.05 0.05 0.2 ]]) = 1361.738 K
# n_i:  596 delta_t:  0.05
# Time 28.929124 s: T([[0.05 0.05 0.2 ]]) = 1361.584 K
# n_i:  597 delta_t:  0.05
# Time 28.979124 s: T([[0.05 0.05 0.2 ]]) = 1361.430 K
# n_i:  598 delta_t:  0.05
# Time 29.029124 s: T([[0.05 0.05 0.2 ]]) = 1361.276 K
# n_i:  599 delta_t:  0.05
# Time 29.079124 s: T([[0.05 0.05 0.2 ]]) = 1361.123 K
# n_i:  600 delta_t:  0.05
# Time 29.129124 s: T([[0.05 0.05 0.2 ]]) = 1360.969 K
# n_i:  601 delta_t:  0.05
# Time 29.179124 s: T([[0.05 0.05 0.2 ]]) = 1360.815 K
# n_i:  602 delta_t:  0.05
# Time 29.229124 s: T([[0.05 0.05 0.2 ]]) = 1360.662 K
# n_i:  603 delta_t:  0.05
# Time 29.279124 s: T([[0.05 0.05 0.2 ]]) = 1360.509 K
# n_i:  604 delta_t:  0.05
# Time 29.329124 s: T([[0.05 0.05 0.2 ]]) = 1360.356 K
# n_i:  605 delta_t:  0.05
# Time 29.379124 s: T([[0.05 0.05 0.2 ]]) = 1360.202 K
# n_i:  606 delta_t:  0.05
# Time 29.429124 s: T([[0.05 0.05 0.2 ]]) = 1360.049 K
# n_i:  607 delta_t:  0.05
# Time 29.479124 s: T([[0.05 0.05 0.2 ]]) = 1359.897 K
# n_i:  608 delta_t:  0.05
# Time 29.529124 s: T([[0.05 0.05 0.2 ]]) = 1359.744 K
# n_i:  609 delta_t:  0.05
# ...
# n_i:  2624 delta_t:  0.05
# Time 130.329124 s: T([[0.05 0.05 0.2 ]]) = 1110.583 K
# n_i:  2625 delta_t:  0.05
# Time 130.379124 s: T([[0.05 0.05 0.2 ]]) = 1110.478 K
# n_i:  2626 delta_t:  0.05
# Time 130.429124 s: T([[0.05 0.05 0.2 ]]) = 1110.373 K
# n_i:  2627 delta_t:  0.05
# Time 130.479124 s: T([[0.05 0.05 0.2 ]]) = 1110.267 K
# n_i:  2628 delta_t:  0.05
# Time 130.529124 s: T([[0.05 0.05 0.2 ]]) = 1110.162 K
# n_i:  2629 delta_t:  0.05
# Time 130.579124 s: T([[0.05 0.05 0.2 ]]) = 1110.057 K
# n_i:  2630 delta_t:  0.05
# Time 130.629124 s: T([[0.05 0.05 0.2 ]]) = 1109.952 K
# n_i:  2631 delta_t:  0.05
# Time 130.679124 s: T([[0.05 0.05 0.2 ]]) = 1109.847 K
# n_i:  2632 delta_t:  0.05
# Time 130.729124 s: T([[0.05 0.05 0.2 ]]) = 1109.742 K
# n_i:  2633 delta_t:  0.05
# Time 130.779124 s: T([[0.05 0.05 0.2 ]]) = 1109.637 K
# n_i:  2634 delta_t:  0.05
# Time 130.829124 s: T([[0.05 0.05 0.2 ]]) = 1109.532 K
# n_i:  2635 delta_t:  0.05
# Time 130.879124 s: T([[0.05 0.05 0.2 ]]) = 1109.427 K
# n_i:  2636 delta_t:  0.05
# Time 130.929124 s: T([[0.05 0.05 0.2 ]]) = 1109.322 K
# n_i:  2637 delta_t:  0.05
# Time 130.979124 s: T([[0.05 0.05 0.2 ]]) = 1109.217 K
# n_i:  2638 delta_t:  0.05
# Time 131.029124 s: T([[0.05 0.05 0.2 ]]) = 1109.112 K
# n_i:  2639 delta_t:  0.05
# Time 131.079124 s: T([[0.05 0.05 0.2 ]]) = 1109.007 K
# n_i:  2640 delta_t:  0.05
# Time 131.129124 s: T([[0.05 0.05 0.2 ]]) = 1108.902 K
# n_i:  2641 delta_t:  0.05
# Time 131.179124 s: T([[0.05 0.05 0.2 ]]) = 1108.797 K
# n_i:  2642 delta_t:  0.05
# Time 131.229124 s: T([[0.05 0.05 0.2 ]]) = 1108.692 K
# n_i:  2643 delta_t:  0.05
# Time 131.279124 s: T([[0.05 0.05 0.2 ]]) = 1108.587 K
# n_i:  2644 delta_t:  0.05
# Time 131.329124 s: T([[0.05 0.05 0.2 ]]) = 1108.482 K
# n_i:  2645 delta_t:  0.05
# Time 131.379124 s: T([[0.05 0.05 0.2 ]]) = 1108.378 K
# n_i:  2646 delta_t:  0.05
# Time 131.429124 s: T([[0.05 0.05 0.2 ]]) = 1108.273 K
# n_i:  2647 delta_t:  0.05
# Time 131.479124 s: T([[0.05 0.05 0.2 ]]) = 1108.168 K
# n_i:  2648 delta_t:  0.05
# Time 131.529124 s: T([[0.05 0.05 0.2 ]]) = 1108.063 K
# n_i:  2649 delta_t:  0.05
# Time 131.579124 s: T([[0.05 0.05 0.2 ]]) = 1107.959 K
# n_i:  2650 delta_t:  0.05
# Time 131.629124 s: T([[0.05 0.05 0.2 ]]) = 1107.854 K
# n_i:  2651 delta_t:  0.05
# Time 131.679124 s: T([[0.05 0.05 0.2 ]]) = 1107.749 K
# n_i:  2652 delta_t:  0.05
# Time 131.729124 s: T([[0.05 0.05 0.2 ]]) = 1107.645 K
# n_i:  2653 delta_t:  0.05
# Time 131.779124 s: T([[0.05 0.05 0.2 ]]) = 1107.540 K
# n_i:  2654 delta_t:  0.05
# Time 131.829124 s: T([[0.05 0.05 0.2 ]]) = 1107.435 K
# n_i:  2655 delta_t:  0.05
# Time 131.879124 s: T([[0.05 0.05 0.2 ]]) = 1107.331 K
# n_i:  2656 delta_t:  0.05
# Time 131.929124 s: T([[0.05 0.05 0.2 ]]) = 1107.226 K
# n_i:  2657 delta_t:  0.05
# Time 131.979124 s: T([[0.05 0.05 0.2 ]]) = 1107.122 K
# n_i:  2658 delta_t:  0.05
# Time 132.029124 s: T([[0.05 0.05 0.2 ]]) = 1107.017 K
# n_i:  2659 delta_t:  0.05
# Time 132.079124 s: T([[0.05 0.05 0.2 ]]) = 1106.912 K
# n_i:  2660 delta_t:  0.05
# Time 132.129124 s: T([[0.05 0.05 0.2 ]]) = 1106.808 K
# n_i:  2661 delta_t:  0.05
# Time 132.179124 s: T([[0.05 0.05 0.2 ]]) = 1106.704 K
# n_i:  2662 delta_t:  0.05
# Time 132.229124 s: T([[0.05 0.05 0.2 ]]) = 1106.599 K
# n_i:  2663 delta_t:  0.05
# Time 132.279124 s: T([[0.05 0.05 0.2 ]]) = 1106.495 K
# n_i:  2664 delta_t:  0.05
# Time 132.329124 s: T([[0.05 0.05 0.2 ]]) = 1106.390 K
# n_i:  2665 delta_t:  0.05
# Time 132.379124 s: T([[0.05 0.05 0.2 ]]) = 1106.286 K
# n_i:  2666 delta_t:  0.05
# Time 132.429124 s: T([[0.05 0.05 0.2 ]]) = 1106.181 K
# n_i:  2667 delta_t:  0.05
# Time 132.479124 s: T([[0.05 0.05 0.2 ]]) = 1106.077 K
# n_i:  2668 delta_t:  0.05
# Time 132.529124 s: T([[0.05 0.05 0.2 ]]) = 1105.973 K
# n_i:  2669 delta_t:  0.05
# Time 132.579124 s: T([[0.05 0.05 0.2 ]]) = 1105.868 K
# n_i:  2670 delta_t:  0.05
# Time 132.629124 s: T([[0.05 0.05 0.2 ]]) = 1105.764 K
# n_i:  2671 delta_t:  0.05
# Time 132.679124 s: T([[0.05 0.05 0.2 ]]) = 1105.660 K
# n_i:  2672 delta_t:  0.05
# Time 132.729124 s: T([[0.05 0.05 0.2 ]]) = 1105.556 K
# n_i:  2673 delta_t:  0.05
# Time 132.779124 s: T([[0.05 0.05 0.2 ]]) = 1105.451 K
# n_i:  2674 delta_t:  0.05
# Time 132.829124 s: T([[0.05 0.05 0.2 ]]) = 1105.347 K
# n_i:  2675 delta_t:  0.05
# Time 132.879124 s: T([[0.05 0.05 0.2 ]]) = 1105.243 K
# n_i:  2676 delta_t:  0.05
# Time 132.929124 s: T([[0.05 0.05 0.2 ]]) = 1105.139 K
# n_i:  2677 delta_t:  0.05
# Time 132.979124 s: T([[0.05 0.05 0.2 ]]) = 1105.035 K
# n_i:  2678 delta_t:  0.05
# Time 133.029124 s: T([[0.05 0.05 0.2 ]]) = 1104.931 K
# n_i:  2679 delta_t:  0.05
# Time 133.079124 s: T([[0.05 0.05 0.2 ]]) = 1104.827 K
# n_i:  2680 delta_t:  0.05
# Time 133.129124 s: T([[0.05 0.05 0.2 ]]) = 1104.722 K
# n_i:  2681 delta_t:  0.05
# Time 133.179124 s: T([[0.05 0.05 0.2 ]]) = 1104.618 K
# n_i:  2682 delta_t:  0.05
# Time 133.229124 s: T([[0.05 0.05 0.2 ]]) = 1104.514 K
# n_i:  2683 delta_t:  0.05
# Time 133.279124 s: T([[0.05 0.05 0.2 ]]) = 1104.410 K
# n_i:  2684 delta_t:  0.05
# Time 133.329124 s: T([[0.05 0.05 0.2 ]]) = 1104.306 K
# n_i:  2685 delta_t:  0.05
# Time 133.379124 s: T([[0.05 0.05 0.2 ]]) = 1104.202 K
# n_i:  2686 delta_t:  0.05
# Time 133.429124 s: T([[0.05 0.05 0.2 ]]) = 1104.098 K
# n_i:  2687 delta_t:  0.05
# Time 133.479124 s: T([[0.05 0.05 0.2 ]]) = 1103.995 K
# n_i:  2688 delta_t:  0.05
# Time 133.529124 s: T([[0.05 0.05 0.2 ]]) = 1103.891 K
# n_i:  2689 delta_t:  0.05
# Time 133.579124 s: T([[0.05 0.05 0.2 ]]) = 1103.787 K
# n_i:  2690 delta_t:  0.05
# Time 133.629124 s: T([[0.05 0.05 0.2 ]]) = 1103.683 K
# n_i:  2691 delta_t:  0.05
# Time 133.679124 s: T([[0.05 0.05 0.2 ]]) = 1103.579 K
# n_i:  2692 delta_t:  0.05
# Time 133.729124 s: T([[0.05 0.05 0.2 ]]) = 1103.475 K
# n_i:  2693 delta_t:  0.05
# Time 133.779124 s: T([[0.05 0.05 0.2 ]]) = 1103.371 K
# n_i:  2694 delta_t:  0.05
# Time 133.829124 s: T([[0.05 0.05 0.2 ]]) = 1103.268 K
# n_i:  2695 delta_t:  0.05
# Time 133.879124 s: T([[0.05 0.05 0.2 ]]) = 1103.164 K
# n_i:  2696 delta_t:  0.05
# Time 133.929124 s: T([[0.05 0.05 0.2 ]]) = 1103.060 K
# n_i:  2697 delta_t:  0.05
# Time 133.979124 s: T([[0.05 0.05 0.2 ]]) = 1102.956 K
# n_i:  2698 delta_t:  0.05
# Time 134.029124 s: T([[0.05 0.05 0.2 ]]) = 1102.853 K
# n_i:  2699 delta_t:  0.05
# Time 134.079124 s: T([[0.05 0.05 0.2 ]]) = 1102.749 K
# n_i:  2700 delta_t:  0.05
# Time 134.129124 s: T([[0.05 0.05 0.2 ]]) = 1102.645 K
# n_i:  2701 delta_t:  0.05
# Time 134.179124 s: T([[0.05 0.05 0.2 ]]) = 1102.542 K
# n_i:  2702 delta_t:  0.05
# Time 134.229124 s: T([[0.05 0.05 0.2 ]]) = 1102.438 K
# n_i:  2703 delta_t:  0.05
# Time 134.279124 s: T([[0.05 0.05 0.2 ]]) = 1102.334 K
# n_i:  2704 delta_t:  0.05
# Time 134.329124 s: T([[0.05 0.05 0.2 ]]) = 1102.231 K
# n_i:  2705 delta_t:  0.05
# Time 134.379124 s: T([[0.05 0.05 0.2 ]]) = 1102.127 K
# n_i:  2706 delta_t:  0.05
# Time 134.429124 s: T([[0.05 0.05 0.2 ]]) = 1102.024 K
# n_i:  2707 delta_t:  0.05
# Time 134.479124 s: T([[0.05 0.05 0.2 ]]) = 1101.920 K
# n_i:  2708 delta_t:  0.05
# Time 134.529124 s: T([[0.05 0.05 0.2 ]]) = 1101.817 K
# n_i:  2709 delta_t:  0.05
# Time 134.579124 s: T([[0.05 0.05 0.2 ]]) = 1101.713 K
# n_i:  2710 delta_t:  0.05
# Time 134.629124 s: T([[0.05 0.05 0.2 ]]) = 1101.610 K
# n_i:  2711 delta_t:  0.05
# Time 134.679124 s: T([[0.05 0.05 0.2 ]]) = 1101.506 K
# n_i:  2712 delta_t:  0.05
# Time 134.729124 s: T([[0.05 0.05 0.2 ]]) = 1101.403 K
# n_i:  2713 delta_t:  0.05
# Time 134.779124 s: T([[0.05 0.05 0.2 ]]) = 1101.300 K
# n_i:  2714 delta_t:  0.05
# Time 134.829124 s: T([[0.05 0.05 0.2 ]]) = 1101.196 K
# n_i:  2715 delta_t:  0.05
# Time 134.879124 s: T([[0.05 0.05 0.2 ]]) = 1101.093 K
# n_i:  2716 delta_t:  0.05
# Time 134.929124 s: T([[0.05 0.05 0.2 ]]) = 1100.990 K
# n_i:  2717 delta_t:  0.05
# Time 134.979124 s: T([[0.05 0.05 0.2 ]]) = 1100.886 K
# n_i:  2718 delta_t:  0.05
# Time 135.029124 s: T([[0.05 0.05 0.2 ]]) = 1100.783 K
# n_i:  2719 delta_t:  0.05
# Time 135.079124 s: T([[0.05 0.05 0.2 ]]) = 1100.680 K
# n_i:  2720 delta_t:  0.05
# Time 135.129124 s: T([[0.05 0.05 0.2 ]]) = 1100.577 K
# n_i:  2721 delta_t:  0.05
# Time 135.179124 s: T([[0.05 0.05 0.2 ]]) = 1100.473 K
# n_i:  2722 delta_t:  0.05
# Time 135.229124 s: T([[0.05 0.05 0.2 ]]) = 1100.370 K
# n_i:  2723 delta_t:  0.05
# Time 135.279124 s: T([[0.05 0.05 0.2 ]]) = 1100.267 K
# n_i:  2724 delta_t:  0.05
# Time 135.329124 s: T([[0.05 0.05 0.2 ]]) = 1100.164 K
# n_i:  2725 delta_t:  0.05
# Time 135.379124 s: T([[0.05 0.05 0.2 ]]) = 1100.061 K
# n_i:  2726 delta_t:  0.05
# Time 135.429124 s: T([[0.05 0.05 0.2 ]]) = 1099.958 K
# n_i:  2727 delta_t:  0.05
# Time 135.479124 s: T([[0.05 0.05 0.2 ]]) = 1099.854 K
# n_i:  2728 delta_t:  0.05
# Time 135.529124 s: T([[0.05 0.05 0.2 ]]) = 1099.751 K
# n_i:  2729 delta_t:  0.05
# Time 135.579124 s: T([[0.05 0.05 0.2 ]]) = 1099.648 K
# n_i:  2730 delta_t:  0.05
# Time 135.629124 s: T([[0.05 0.05 0.2 ]]) = 1099.545 K
# n_i:  2731 delta_t:  0.05
# Time 135.679124 s: T([[0.05 0.05 0.2 ]]) = 1099.442 K
# n_i:  2732 delta_t:  0.05
# Time 135.729124 s: T([[0.05 0.05 0.2 ]]) = 1099.339 K
# n_i:  2733 delta_t:  0.05
# Time 135.779124 s: T([[0.05 0.05 0.2 ]]) = 1099.236 K
# n_i:  2734 delta_t:  0.05
# Time 135.829124 s: T([[0.05 0.05 0.2 ]]) = 1099.133 K
# n_i:  2735 delta_t:  0.05
# Time 135.879124 s: T([[0.05 0.05 0.2 ]]) = 1099.030 K
# n_i:  2736 delta_t:  0.05
# Time 135.929124 s: T([[0.05 0.05 0.2 ]]) = 1098.928 K
# n_i:  2737 delta_t:  0.05
# Time 135.979124 s: T([[0.05 0.05 0.2 ]]) = 1098.825 K
# n_i:  2738 delta_t:  0.05
# Time 136.029124 s: T([[0.05 0.05 0.2 ]]) = 1098.722 K
# n_i:  2739 delta_t:  0.05
# Time 136.079124 s: T([[0.05 0.05 0.2 ]]) = 1098.619 K
# n_i:  2740 delta_t:  0.05
# Time 136.129124 s: T([[0.05 0.05 0.2 ]]) = 1098.516 K
# n_i:  2741 delta_t:  0.05
# Time 136.179124 s: T([[0.05 0.05 0.2 ]]) = 1098.413 K
# n_i:  2742 delta_t:  0.05
# Time 136.229124 s: T([[0.05 0.05 0.2 ]]) = 1098.311 K
# n_i:  2743 delta_t:  0.05
# Time 136.279124 s: T([[0.05 0.05 0.2 ]]) = 1098.208 K
# n_i:  2744 delta_t:  0.05
# Time 136.329124 s: T([[0.05 0.05 0.2 ]]) = 1098.105 K
# n_i:  2745 delta_t:  0.05
# Time 136.379124 s: T([[0.05 0.05 0.2 ]]) = 1098.002 K
# n_i:  2746 delta_t:  0.05
# Time 136.429124 s: T([[0.05 0.05 0.2 ]]) = 1097.900 K
# n_i:  2747 delta_t:  0.05
# Time 136.479124 s: T([[0.05 0.05 0.2 ]]) = 1097.797 K
# n_i:  2748 delta_t:  0.05
# Time 136.529124 s: T([[0.05 0.05 0.2 ]]) = 1097.694 K
# n_i:  2749 delta_t:  0.05
# Time 136.579124 s: T([[0.05 0.05 0.2 ]]) = 1097.592 K
# n_i:  2750 delta_t:  0.05
# Time 136.629124 s: T([[0.05 0.05 0.2 ]]) = 1097.489 K
# n_i:  2751 delta_t:  0.05
# Time 136.679124 s: T([[0.05 0.05 0.2 ]]) = 1097.386 K
# n_i:  2752 delta_t:  0.05
# Time 136.729124 s: T([[0.05 0.05 0.2 ]]) = 1097.284 K
# n_i:  2753 delta_t:  0.05
# Time 136.779124 s: T([[0.05 0.05 0.2 ]]) = 1097.181 K
# n_i:  2754 delta_t:  0.05
# Time 136.829124 s: T([[0.05 0.05 0.2 ]]) = 1097.079 K
# n_i:  2755 delta_t:  0.05
# Time 136.879124 s: T([[0.05 0.05 0.2 ]]) = 1096.976 K
# n_i:  2756 delta_t:  0.05
# Time 136.929124 s: T([[0.05 0.05 0.2 ]]) = 1096.874 K
# n_i:  2757 delta_t:  0.05
# Time 136.979124 s: T([[0.05 0.05 0.2 ]]) = 1096.771 K
# n_i:  2758 delta_t:  0.05
# Time 137.029124 s: T([[0.05 0.05 0.2 ]]) = 1096.669 K
# n_i:  2759 delta_t:  0.05
# Time 137.079124 s: T([[0.05 0.05 0.2 ]]) = 1096.566 K
# n_i:  2760 delta_t:  0.05
# Time 137.129124 s: T([[0.05 0.05 0.2 ]]) = 1096.464 K
# n_i:  2761 delta_t:  0.05
# Time 137.179124 s: T([[0.05 0.05 0.2 ]]) = 1096.362 K
# n_i:  2762 delta_t:  0.05
# Time 137.229124 s: T([[0.05 0.05 0.2 ]]) = 1096.259 K
# n_i:  2763 delta_t:  0.05
# Time 137.279124 s: T([[0.05 0.05 0.2 ]]) = 1096.157 K
# n_i:  2764 delta_t:  0.05
# Time 137.329124 s: T([[0.05 0.05 0.2 ]]) = 1096.055 K
# n_i:  2765 delta_t:  0.05
# Time 137.379124 s: T([[0.05 0.05 0.2 ]]) = 1095.952 K
# n_i:  2766 delta_t:  0.05
# Time 137.429124 s: T([[0.05 0.05 0.2 ]]) = 1095.850 K
# n_i:  2767 delta_t:  0.05
# Time 137.479124 s: T([[0.05 0.05 0.2 ]]) = 1095.748 K
# n_i:  2768 delta_t:  0.05
# Time 137.529124 s: T([[0.05 0.05 0.2 ]]) = 1095.646 K
# n_i:  2769 delta_t:  0.05
# Time 137.579124 s: T([[0.05 0.05 0.2 ]]) = 1095.543 K
# n_i:  2770 delta_t:  0.05
# Time 137.629124 s: T([[0.05 0.05 0.2 ]]) = 1095.441 K
# n_i:  2771 delta_t:  0.05
# Time 137.679124 s: T([[0.05 0.05 0.2 ]]) = 1095.339 K
# n_i:  2772 delta_t:  0.05
# Time 137.729124 s: T([[0.05 0.05 0.2 ]]) = 1095.237 K
# n_i:  2773 delta_t:  0.05
# Time 137.779124 s: T([[0.05 0.05 0.2 ]]) = 1095.135 K
# n_i:  2774 delta_t:  0.05
# Time 137.829124 s: T([[0.05 0.05 0.2 ]]) = 1095.033 K
# n_i:  2775 delta_t:  0.05
# Time 137.879124 s: T([[0.05 0.05 0.2 ]]) = 1094.931 K
# n_i:  2776 delta_t:  0.05
# Time 137.929124 s: T([[0.05 0.05 0.2 ]]) = 1094.829 K
# n_i:  2777 delta_t:  0.05
# Time 137.979124 s: T([[0.05 0.05 0.2 ]]) = 1094.726 K
# n_i:  2778 delta_t:  0.05
# Time 138.029124 s: T([[0.05 0.05 0.2 ]]) = 1094.624 K
# n_i:  2779 delta_t:  0.05
# Time 138.079124 s: T([[0.05 0.05 0.2 ]]) = 1094.522 K
# n_i:  2780 delta_t:  0.05
# Time 138.129124 s: T([[0.05 0.05 0.2 ]]) = 1094.420 K
# n_i:  2781 delta_t:  0.05
# Time 138.179124 s: T([[0.05 0.05 0.2 ]]) = 1094.319 K
# n_i:  2782 delta_t:  0.05
# Time 138.229124 s: T([[0.05 0.05 0.2 ]]) = 1094.217 K
# n_i:  2783 delta_t:  0.05
# Time 138.279124 s: T([[0.05 0.05 0.2 ]]) = 1094.115 K
# n_i:  2784 delta_t:  0.05
# Time 138.329124 s: T([[0.05 0.05 0.2 ]]) = 1094.013 K
# n_i:  2785 delta_t:  0.05
# Time 138.379124 s: T([[0.05 0.05 0.2 ]]) = 1093.911 K
# n_i:  2786 delta_t:  0.05
# Time 138.429124 s: T([[0.05 0.05 0.2 ]]) = 1093.809 K
# n_i:  2787 delta_t:  0.05
# Time 138.479124 s: T([[0.05 0.05 0.2 ]]) = 1093.707 K
# n_i:  2788 delta_t:  0.05
# Time 138.529124 s: T([[0.05 0.05 0.2 ]]) = 1093.605 K
# n_i:  2789 delta_t:  0.05
# Time 138.579124 s: T([[0.05 0.05 0.2 ]]) = 1093.504 K
# n_i:  2790 delta_t:  0.05
# Time 138.629124 s: T([[0.05 0.05 0.2 ]]) = 1093.402 K
# n_i:  2791 delta_t:  0.05
# Time 138.679124 s: T([[0.05 0.05 0.2 ]]) = 1093.300 K
# n_i:  2792 delta_t:  0.05
# Time 138.729124 s: T([[0.05 0.05 0.2 ]]) = 1093.198 K
# n_i:  2793 delta_t:  0.05
# Time 138.779124 s: T([[0.05 0.05 0.2 ]]) = 1093.097 K
# n_i:  2794 delta_t:  0.05
# Time 138.829124 s: T([[0.05 0.05 0.2 ]]) = 1092.995 K
# n_i:  2795 delta_t:  0.05
# Time 138.879124 s: T([[0.05 0.05 0.2 ]]) = 1092.893 K
# n_i:  2796 delta_t:  0.05
# Time 138.929124 s: T([[0.05 0.05 0.2 ]]) = 1092.792 K
# n_i:  2797 delta_t:  0.05
# Time 138.979124 s: T([[0.05 0.05 0.2 ]]) = 1092.690 K
# n_i:  2798 delta_t:  0.05
# Time 139.029124 s: T([[0.05 0.05 0.2 ]]) = 1092.588 K
# n_i:  2799 delta_t:  0.05
# Time 139.079124 s: T([[0.05 0.05 0.2 ]]) = 1092.487 K
# n_i:  2800 delta_t:  0.05
# Time 139.129124 s: T([[0.05 0.05 0.2 ]]) = 1092.385 K
# n_i:  2801 delta_t:  0.05
# Time 139.179124 s: T([[0.05 0.05 0.2 ]]) = 1092.284 K
# n_i:  2802 delta_t:  0.05
# Time 139.229124 s: T([[0.05 0.05 0.2 ]]) = 1092.182 K
# n_i:  2803 delta_t:  0.05
# Time 139.279124 s: T([[0.05 0.05 0.2 ]]) = 1092.081 K
# n_i:  2804 delta_t:  0.05
# Time 139.329124 s: T([[0.05 0.05 0.2 ]]) = 1091.979 K
# n_i:  2805 delta_t:  0.05
# Time 139.379124 s: T([[0.05 0.05 0.2 ]]) = 1091.878 K
# n_i:  2806 delta_t:  0.05
# Time 139.429124 s: T([[0.05 0.05 0.2 ]]) = 1091.776 K
# n_i:  2807 delta_t:  0.05
# Time 139.479124 s: T([[0.05 0.05 0.2 ]]) = 1091.675 K
# n_i:  2808 delta_t:  0.05
# Time 139.529124 s: T([[0.05 0.05 0.2 ]]) = 1091.574 K
# n_i:  2809 delta_t:  0.05
# Time 139.579124 s: T([[0.05 0.05 0.2 ]]) = 1091.472 K
# n_i:  2810 delta_t:  0.05
# Time 139.629124 s: T([[0.05 0.05 0.2 ]]) = 1091.371 K
# n_i:  2811 delta_t:  0.05
# Time 139.679124 s: T([[0.05 0.05 0.2 ]]) = 1091.269 K
# n_i:  2812 delta_t:  0.05
# Time 139.729124 s: T([[0.05 0.05 0.2 ]]) = 1091.168 K
# n_i:  2813 delta_t:  0.05
# Time 139.779124 s: T([[0.05 0.05 0.2 ]]) = 1091.067 K
# n_i:  2814 delta_t:  0.05
# Time 139.829124 s: T([[0.05 0.05 0.2 ]]) = 1090.966 K
# n_i:  2815 delta_t:  0.05
# Time 139.879124 s: T([[0.05 0.05 0.2 ]]) = 1090.864 K
# n_i:  2816 delta_t:  0.05
# Time 139.929124 s: T([[0.05 0.05 0.2 ]]) = 1090.763 K
# n_i:  2817 delta_t:  0.05
# Time 139.979124 s: T([[0.05 0.05 0.2 ]]) = 1090.662 K
# n_i:  2818 delta_t:  0.05
# Time 140.029124 s: T([[0.05 0.05 0.2 ]]) = 1090.561 K
# n_i:  2819 delta_t:  0.05
# It took 19.585952758789062 s to solve the problem.
# [stdout:5] Starting the time loop...
# It took 19.586504697799683 s to solve the problem.
# [stdout:6] Starting the time loop...
# It took 19.586466312408447 s to solve the problem.
# [stdout:0] Starting the time loop...
# It took 19.585686445236206 s to solve the problem.
# %px:   0%|          | 0/9 [00:00<?, ?tasks/s]

# %%
# %%px
#
# # post-processing: --> open in Paraview with ADIOS2VTXReader
# T_out = fem.Function(V)
# writer = VTXWriter(MPI.COMM_WORLD, "output/T.bp", T_out, engine="BP4")
#
# for solution_, time_ in zip(Tracker_solution_function, Tracker_time):
#     T_out.x.array[:] = solution_
#     T_out.x.scatter_forward()
#     writer.write(time_)
#
# writer.close()
# Out:
# %px:   0%|          | 0/9 [00:00<?, ?tasks/s]

# %%
# %%px
#
# if rank_contains_cellid == MPI.COMM_WORLD.Get_rank():
#     #print("T_tracker", T_tracker[:, 0])
#     #print("T_tracker", T_tracker[:, 0].shape)
#     #plot the temperature curve of T_tracker
#     plt.figure()
#     plt.plot(Tracker_time, T_tracker)
#     #plt.plot(np.arange(0, n_timesteps) * delta_t.value, T_tracker)
#     plt.xlabel("Time [s]")
#     plt.ylabel("Temperature [K]")
#     plt.title("Temperature at x=0.05, y=0.05, z=0.2, dt_max=0.05, F2val")
#     plt.grid()
#     plt.savefig("temperature_maxdt005_F2val.png")
#     plt.show()
#
#     T_tracker_derivative = np.gradient(np.array(T_tracker), np.array(Tracker_time))
#     plt.figure()
#     plt.plot(Tracker_time, T_tracker_derivative)
#     plt.ylim([-25, 25])
#     plt.xlabel("Time [s]")
#     plt.ylabel("Temperature Derivative [K/s]")
#     plt.title("Temperature Derivative at x=0.05, y=0.05, z=0.2, dt_max=0.05, F2val")
#     plt.grid()
#     plt.savefig("derivative_maxdt005_F2val.png")
#     plt.show()
# Out:
# [output:8]
# [output:8]

# %%
# %%px
# plotter.close()

# %%
import pyvista
from dolfinx.plot import vtk_mesh

# Get VTK-compatible mesh and cell type
grid = pyvista.UnstructuredGrid(*vtk_mesh(msh, msh.topology.dim))

# Add solution values to the grid
grid.point_data["Temperature"] = T_n.x.array.real

# Plot
plotter = pyvista.Plotter()
plotter.add_mesh(grid, scalars="Temperature", cmap="coolwarm", show_edges=True)
plotter.add_scalar_bar("Temperature")
plotter.show()

# %%
import pyvista
from dolfinx.plot import vtk_mesh

# Visualize solution
pyvista.start_xvfb()
pyvista_cells, cell_types, geometry = vtk_mesh(V)
grid = pyvista.UnstructuredGrid(pyvista_cells, cell_types, geometry)
grid.point_data["u"] = uh.x.array
grid.set_active_scalars("u")

plotter = pyvista.Plotter()
plotter.add_text("uh", position="upper_edge", font_size=14, color="black")
plotter.add_mesh(grid, show_edges=True)
plotter.view_xy()
plotter.show()
if not pyvista.OFF_SCREEN:
    plotter.show()
else:
    figure = plotter.screenshot("robin_neumann_dirichlet.png")

# %%
import numpy as np

# Get the coordinates of the mesh points
coordinates = msh.geometry.x

# Find the indices of points where y = 0.5 (with a tolerance for floating-point comparisons)
y_target = 0.5
tolerance = 1e-6
indices = np.where(np.abs(coordinates[:, 1] - y_target) < tolerance)[0]

# Extract the x and z coordinates of these points
x_coords = coordinates[indices, 0]
z_coords = coordinates[indices, 2]

# Extract the solution values at these points
solution_values = uh.x.array[indices]

# Combine x, z, and solution values for visualization
xz_plane = np.column_stack((x_coords, z_coords, solution_values))

# Sort by x and z for better visualization
xz_plane = xz_plane[np.lexsort((xz_plane[:, 1], xz_plane[:, 0]))]

# Print or process the reshaped solution
print("x-z plane at y=0.5 (x, z, solution):")
print(xz_plane)

# %%
# We now find the degrees-of-freedom that are associated with the
# boundary facets using {py:func}`locate_dofs_topological
# <dolfinx.fem.locate_dofs_topological>`:

dofs = fem.locate_dofs_topological(V=V, entity_dim=2, entities=facets_heatplate)

# %%
# and use {py:func}`dirichletbc <dolfinx.fem.dirichletbc>` to create a
# {py:class}`DirichletBC <dolfinx.fem.DirichletBC>` class that
# represents the boundary condition:

bc_heatplate = fem.dirichletbc(value=ScalarType(300), dofs=dofs, V=V)

# %%
from ufl import (FacetNormal, Measure, SpatialCoordinate, TestFunction, TrialFunction, 
                 div, dot, dx, grad, inner, lhs, rhs)
from dolfinx.mesh import create_unit_square, locate_entities, meshtags

fdim = mesh.topology.dim - 1

facet_tag = meshtags(mesh, fdim, facet_indices[sorted_facets], facet_markers[sorted_facets])

ds = Measure("ds", domain=mesh, subdomain_data=facet_tag)

# %%
# +
#problem = LinearProblem(a, L, bcs=[bc], petsc_options={"ksp_type": "preonly", "pc_type": "lu"})
start_time=time.time()
problem = LinearProblem(a, L, bcs=[bc], petsc_options={"ksp_type": "preonly", "pc_type": "jacobi", "ksp_rtol": 1e-6}) # jacobi is faster (2x) than lu (for 2d); over 100x for 3d! (0.13s vs 24s). fastest: ilu preonly, kaczmarz preonly, jacobi preonly
end_time=time.time()
print("Time taken for problem setup in ms: ", (end_time-start_time)*1000)
start_time=time.time()
uh = problem.solve()
end_time=time.time()
print("Time taken to solve the problem in ms: ", (end_time-start_time)*1000)
#print number of degrees of freedom
print("Number of degrees of freedom: ", problem.A.getSize()[0])
# -

# %% [markdown]
# Results:
# 200x200x200: setup time: 4s
# solvers time:
#     jacobi preonly: 63s
#     ilu preonly: 65s
#     kaczmarz preonly: 64s
#     gamg preonly: 102s

# %%
# %%px
#
# # -
# with io.VTKFile(umesh.comm, "out_umesh/umesh.vtk", "w") as file:
#     file.write_mesh(umesh)
#     file.write_function(uh)
# # -

# %%
# +
try:
    import pyvista

    cells, types, x = plot.vtk_mesh(V)
    grid = pyvista.UnstructuredGrid(cells, types, x)
    grid.point_data["u"] = uh.x.array.real
    grid.set_active_scalars("u")
    plotter = pyvista.Plotter()
    #plotter.add_mesh(grid, show_edges=True)
    #warped = grid.warp_by_scalar()
    #plotter.add_mesh(warped)
    plotter.add_mesh(grid)
    plotter.show()
    if pyvista.OFF_SCREEN:
        print("Rendering off screen")
        pyvista.start_xvfb(wait=0.1)
        plotter.screenshot("uh_poisson.png")
    else:
        plotter.show()
except ModuleNotFoundError:
    print("'pyvista' is required to visualise the solution.")
    print("To install pyvista with pip: 'python3 -m pip install pyvista'.")
# -
